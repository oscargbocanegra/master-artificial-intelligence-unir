# %% [markdown]
# **Universidad Internacional de La Rioja (UNIR) - Máster Universitario en Inteligencia Artificial - Procesamiento del Lenguaje Natural**

# %% [markdown]
# ***
#
# Fecha: Octubre 9 2023
# ***

# %% [markdown]
# <span style="font-size: 20pt; font-weight: bold; color: #0098cd;">Trabajo: Named-Entity Recognition</span>
#
# **Objetivos**
#
# Con esta actividad se tratará de que el alumno se familiarice con el manejo de la librería spacy, así como con los conceptos básicos de manejo de las técnicas NER
#
# **Descripción**
#
# En esta actividad debes procesar de forma automática un texto en lenguaje natural para detectar características básicas en el mismo, y para identificar y etiquetar las ocurrencias de conceptos como localización, moneda, empresas, etc.
#
# En la primera parte del ejercicio se proporciona un código fuente a través del cual se lee un archivo de texto y se realiza un preprocesado del mismo. En esta parte el alumno tan sólo debe ejecutar y entender el código proporcionado.
#
# En la segunda parte del ejercicio se plantean una serie de preguntas que deben ser respondidas por el alumno. Cada pregunta deberá responderse con un fragmento de código fuente que esté acompañado de la explicación correspondiente. Para elaborar el código solicitado, el alumno deberá visitar la documentación de la librería spacy, cuyos enlaces se proporcionarán donde corresponda.

# %% [markdown]
# # Parte 1: carga y preprocesamiento del texto a analizar

# %% [markdown]
# Observa las diferentes librerías que se están importando.

# %%
import pathlib
import spacy
from spacy import displacy
import en_core_web_sm

# %% [markdown]
# El siguiente código simplemente carga y preprocesa el texto. Para ello, lo primero que hace es cargar un modelo de lenguaje previamente entrenado. En este caso, se utiliza <i>en_core_web_sm</i>:
#
# https://spacy.io/models/en#en_core_web_sm
#
# Al cargar el modelo de lenguaje se genera un <i>Pipeline</i>, que nos permite realizar las diferentes tareas. En este caso, vamos a utilizar el pipeline para hacer un preprocesamiento básico, que consiste en tokenizar el texto.
#
# Al final del código proporcionado <i>doc</i> representa una versión tokenizada del texto leído.

# %%
nlp = en_core_web_sm.load()
file_name = "barack-obama-speech.txt"
doc = nlp(pathlib.Path(file_name).read_text(encoding="utf-8"))

# %% [markdown]
# ### Playground
#
# La variable <i>doc</i> es un objeto de la clase <i>Doc</i> (https://spacy.io/api/doc)
#
# Visita la documentación de dicha clase y experimenta probando las diferentes funciones y atributos

# %%
# Puedes insertar aquí código de pruebas para experimentar con las diferentes funciones y atributos de 'doc'.
len(doc)
# Out:
# 1939

# %% [markdown]
# # Parte 2: preguntas

# %% [markdown]
# Para responder a cada una de las preguntas planteadas deberás aportar tanto el código fuente con el cual puedes conseguir la respuesta, como una explicación válida de la respuesta y de la forma de obtenerla.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 1.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuántas palabras tiene el texto?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
len(doc)
# Out:
# 1939

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# </br> * Con la funcion len, se puede obtener la cantidad de tokens que tiene el documento.
# <hr>

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 2.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuántas oraciones tiene el texto?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
oraciones = list(doc.sents)
# Retornando el numero de oraciones.
len(oraciones)
# Out:
# 83

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# </br> * Con la funcion list(doc.sents) se cuentan y separan la cantidad de oraciones, teniendo en cuenta que el separador es el punto.
# </br> * Con la funcion len() obtenemos la cantidad de oraciones separadas en la linea anterior.
# <hr>

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 3.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuál el número de palabras de la oración más grande? ¿Cual es dicha oración?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
total_palabras = 0
for oracion in doc.sents:
    num_palabras = len([token for token in oracion if not token.is_punct])
    if num_palabras > total_palabras:
        total_palabras = num_palabras

print ('Numero de palabras en la oracion mas larga ' + str(total_palabras))
# Out:
# Numero de palabras en la oracion mas larga 61

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# </br> * Se crea un for para recorrer las oraciones en el documento. Posteriormente se divide la oracion en palabras para contar la cantidad de tokens actualizando la longitud  maxima de palabras comparando con la anterior oracion.
# <hr>

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 4.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cómo puedes obtener el lema, el sufijo y el análisis morfológico de cada token?</span>
#
# Recomendación: si no lo has hecho ya, visita la documentación de la clase <i>Token</i>: https://spacy.io/api/token

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
# Iterando los tokens en el documento.
lema = None
sufijo = None
analisis = None
for token in doc:
    # Se obtiene el lema, sufijo, y analisis morfologico a partir del token.
    lema = token.lemma_
    sufijo = token.suffix_
    analisis = token.morph

    # Retornando los valores para cada token analizado.
    print(f'Token: {token.text}, Lema: {lema}, Sufijo: {sufijo}, Análisis Morfológico: {analisis}')
# Out:
# Token: “, Lema: ", Sufijo: “, Análisis Morfológico: PunctSide=Ini|PunctType=Quot
# Token: Hello, Lema: Hello, Sufijo: llo, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: Chicago, Lema: Chicago, Sufijo: ago, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: If, Lema: if, Sufijo: If, Análisis Morfológico:
# Token: there, Lema: there, Sufijo: ere, Análisis Morfológico:
# Token: is, Lema: be, Sufijo: is, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: anyone, Lema: anyone, Sufijo: one, Análisis Morfológico: Number=Sing|PronType=Ind
# Token: out, Lema: out, Sufijo: out, Análisis Morfológico:
# Token: there, Lema: there, Sufijo: ere, Análisis Morfológico: PronType=Dem
# Token: who, Lema: who, Sufijo: who, Análisis Morfológico:
# Token: still, Lema: still, Sufijo: ill, Análisis Morfológico:
# Token: doubts, Lema: doubt, Sufijo: bts, Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico:
# Token: America, Lema: America, Sufijo: ica, Análisis Morfológico: Number=Sing
# Token: is, Lema: be, Sufijo: is, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: a, Lema: a, Sufijo: a, Análisis Morfológico: Definite=Ind|PronType=Art
# Token: place, Lema: place, Sufijo: ace, Análisis Morfológico: Number=Sing
# Token: where, Lema: where, Sufijo: ere, Análisis Morfológico:
# Token: all, Lema: all, Sufijo: all, Análisis Morfológico:
# Token: things, Lema: thing, Sufijo: ngs, Análisis Morfológico: Number=Plur
# Token: are, Lema: be, Sufijo: are, Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
# Token: possible, Lema: possible, Sufijo: ble, Análisis Morfológico: Degree=Pos
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: who, Lema: who, Sufijo: who, Análisis Morfológico:
# Token: still, Lema: still, Sufijo: ill, Análisis Morfológico:
# Token: wonders, Lema: wonder, Sufijo: ers, Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: if, Lema: if, Sufijo: if, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: dream, Lema: dream, Sufijo: eam, Análisis Morfológico: Number=Sing
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: our, Lema: our, Sufijo: our, Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# Token: founders, Lema: founder, Sufijo: ers, Análisis Morfológico: Number=Plur
# Token: is, Lema: be, Sufijo: is, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: alive, Lema: alive, Sufijo: ive, Análisis Morfológico: Degree=Pos
# Token: in, Lema: in, Sufijo: in, Análisis Morfológico:
# Token: our, Lema: our, Sufijo: our, Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# Token: time, Lema: time, Sufijo: ime, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: who, Lema: who, Sufijo: who, Análisis Morfológico:
# Token: still, Lema: still, Sufijo: ill, Análisis Morfológico:
# Token: questions, Lema: question, Sufijo: ons, Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: power, Lema: power, Sufijo: wer, Análisis Morfológico: Number=Sing
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: our, Lema: our, Sufijo: our, Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# Token: democracy, Lema: democracy, Sufijo: acy, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: tonight, Lema: tonight, Sufijo: ght, Análisis Morfológico: Number=Sing
# Token: is, Lema: be, Sufijo: is, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: your, Lema: your, Sufijo: our, Análisis Morfológico: Person=2|Poss=Yes|PronType=Prs
# Token: answer, Lema: answer, Sufijo: wer, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: It, Lema: it, Sufijo: It, Análisis Morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# Token: ’s, Lema: be, Sufijo: ’s, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: answer, Lema: answer, Sufijo: wer, Análisis Morfológico: Number=Sing
# Token: told, Lema: tell, Sufijo: old, Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
# Token: by, Lema: by, Sufijo: by, Análisis Morfológico:
# Token: lines, Lema: line, Sufijo: nes, Análisis Morfológico: Number=Plur
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico: PronType=Rel
# Token: stretched, Lema: stretch, Sufijo: hed, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: around, Lema: around, Sufijo: und, Análisis Morfológico:
# Token: schools, Lema: school, Sufijo: ols, Análisis Morfológico: Number=Plur
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: churches, Lema: church, Sufijo: hes, Análisis Morfológico: Number=Plur
# Token: in, Lema: in, Sufijo: in, Análisis Morfológico:
# Token: numbers, Lema: number, Sufijo: ers, Análisis Morfológico: Number=Plur
# Token: this, Lema: this, Sufijo: his, Análisis Morfológico: Number=Sing|PronType=Dem
# Token: nation, Lema: nation, Sufijo: ion, Análisis Morfológico: Number=Sing
# Token: has, Lema: have, Sufijo: has, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: never, Lema: never, Sufijo: ver, Análisis Morfológico:
# Token: seen, Lema: see, Sufijo: een, Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: by, Lema: by, Sufijo: by, Análisis Morfológico:
# Token: people, Lema: people, Sufijo: ple, Análisis Morfológico: Number=Plur
# Token: who, Lema: who, Sufijo: who, Análisis Morfológico:
# Token: waited, Lema: wait, Sufijo: ted, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: three, Lema: three, Sufijo: ree, Análisis Morfológico: NumType=Card
# Token: hours, Lema: hour, Sufijo: urs, Análisis Morfológico: Number=Plur
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: four, Lema: four, Sufijo: our, Análisis Morfológico: NumType=Card
# Token: hours, Lema: hour, Sufijo: urs, Análisis Morfológico: Number=Plur
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: many, Lema: many, Sufijo: any, Análisis Morfológico: Degree=Pos
# Token: for, Lema: for, Sufijo: for, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: first, Lema: first, Sufijo: rst, Análisis Morfológico: Degree=Pos
# Token: time, Lema: time, Sufijo: ime, Análisis Morfológico: Number=Sing
# Token: in, Lema: in, Sufijo: in, Análisis Morfológico:
# Token: their, Lema: their, Sufijo: eir, Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# Token: lives, Lema: life, Sufijo: ves, Análisis Morfológico: Number=Plur
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: because, Lema: because, Sufijo: use, Análisis Morfológico:
# Token: they, Lema: they, Sufijo: hey, Análisis Morfológico: Case=Nom|Number=Plur|Person=3|PronType=Prs
# Token: believed, Lema: believe, Sufijo: ved, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico:
# Token: this, Lema: this, Sufijo: his, Análisis Morfológico: Number=Sing|PronType=Dem
# Token: time, Lema: time, Sufijo: ime, Análisis Morfológico: Number=Sing
# Token: must, Lema: must, Sufijo: ust, Análisis Morfológico: VerbForm=Fin
# Token: be, Lema: be, Sufijo: be, Análisis Morfológico: VerbForm=Inf
# Token: different, Lema: different, Sufijo: ent, Análisis Morfológico: Degree=Pos
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico:
# Token: their, Lema: their, Sufijo: eir, Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# Token: voices, Lema: voice, Sufijo: ces, Análisis Morfológico: Number=Plur
# Token: could, Lema: could, Sufijo: uld, Análisis Morfológico: VerbForm=Fin
# Token: be, Lema: be, Sufijo: be, Análisis Morfológico: VerbForm=Inf
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico: Number=Sing|PronType=Dem
# Token: difference, Lema: difference, Sufijo: nce, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: It, Lema: it, Sufijo: It, Análisis Morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# Token: ’s, Lema: be, Sufijo: ’s, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: answer, Lema: answer, Sufijo: wer, Análisis Morfológico: Number=Sing
# Token: spoken, Lema: speak, Sufijo: ken, Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
# Token: by, Lema: by, Sufijo: by, Análisis Morfológico:
# Token: young, Lema: young, Sufijo: ung, Análisis Morfológico: Degree=Pos
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: old, Lema: old, Sufijo: old, Análisis Morfológico: Degree=Pos
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: rich, Lema: rich, Sufijo: ich, Análisis Morfológico: Degree=Pos
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: poor, Lema: poor, Sufijo: oor, Análisis Morfológico: Degree=Pos
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: Democrat, Lema: Democrat, Sufijo: rat, Análisis Morfológico: Number=Sing
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: Republican, Lema: Republican, Sufijo: can, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: black, Lema: black, Sufijo: ack, Análisis Morfológico: Degree=Pos
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: white, Lema: white, Sufijo: ite, Análisis Morfológico: Degree=Pos
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: Hispanic, Lema: hispanic, Sufijo: nic, Análisis Morfológico: Degree=Pos
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: Asian, Lema: asian, Sufijo: ian, Análisis Morfológico: Degree=Pos
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: Native, Lema: Native, Sufijo: ive, Análisis Morfológico: Number=Sing
# Token: American, Lema: American, Sufijo: can, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: gay, Lema: gay, Sufijo: gay, Análisis Morfológico: Degree=Pos
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: straight, Lema: straight, Sufijo: ght, Análisis Morfológico: Degree=Pos
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: disabled, Lema: disabled, Sufijo: led, Análisis Morfológico: Degree=Pos
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: not, Lema: not, Sufijo: not, Análisis Morfológico: Polarity=Neg
# Token: disabled, Lema: disabled, Sufijo: led, Análisis Morfológico: Degree=Pos
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token: Americans, Lema: american, Sufijo: ans, Análisis Morfológico: Number=Plur
# Token: who, Lema: who, Sufijo: who, Análisis Morfológico:
# Token: sent, Lema: send, Sufijo: ent, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: a, Lema: a, Sufijo: a, Análisis Morfológico: Definite=Ind|PronType=Art
# Token: message, Lema: message, Sufijo: age, Análisis Morfológico: Number=Sing
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: world, Lema: world, Sufijo: rld, Análisis Morfológico: Number=Sing
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico:
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: have, Lema: have, Sufijo: ave, Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
# Token: never, Lema: never, Sufijo: ver, Análisis Morfológico:
# Token: been, Lema: be, Sufijo: een, Análisis Morfológico: Tense=Past|VerbForm=Part
# Token: just, Lema: just, Sufijo: ust, Análisis Morfológico:
# Token: a, Lema: a, Sufijo: a, Análisis Morfológico: Definite=Ind|PronType=Art
# Token: collection, Lema: collection, Sufijo: ion, Análisis Morfológico: Number=Sing
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: individuals, Lema: individual, Sufijo: als, Análisis Morfológico: Number=Plur
# Token: or, Lema: or, Sufijo: or, Análisis Morfológico: ConjType=Cmp
# Token: a, Lema: a, Sufijo: a, Análisis Morfológico: Definite=Ind|PronType=Art
# Token: collection, Lema: collection, Sufijo: ion, Análisis Morfológico: Number=Sing
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: red, Lema: red, Sufijo: red, Análisis Morfológico: Degree=Pos
# Token: states, Lema: state, Sufijo: tes, Análisis Morfológico: Number=Plur
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: blue, Lema: blue, Sufijo: lue, Análisis Morfológico: Degree=Pos
# Token: states, Lema: state, Sufijo: tes, Análisis Morfológico: Number=Plur
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: We, Lema: we, Sufijo: We, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: are, Lema: be, Sufijo: are, Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: always, Lema: always, Sufijo: ays, Análisis Morfológico:
# Token: will, Lema: will, Sufijo: ill, Análisis Morfológico: VerbForm=Fin
# Token: be, Lema: be, Sufijo: be, Análisis Morfológico: VerbForm=Inf
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: United, Lema: United, Sufijo: ted, Análisis Morfológico: Number=Sing
# Token: States, Lema: States, Sufijo: tes, Análisis Morfológico: Number=Sing
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: America, Lema: America, Sufijo: ica, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: It, Lema: it, Sufijo: It, Análisis Morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# Token: ’s, Lema: be, Sufijo: ’s, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: answer, Lema: answer, Sufijo: wer, Análisis Morfológico: Number=Sing
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico: PronType=Rel
# Token: led, Lema: lead, Sufijo: led, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: those, Lema: those, Sufijo: ose, Análisis Morfológico: Number=Plur|PronType=Dem
# Token: who, Lema: who, Sufijo: who, Análisis Morfológico:
# Token: ’ve, Lema: ’ve, Sufijo: ’ve, Análisis Morfológico: Tense=Pres|VerbForm=Fin
# Token: been, Lema: been, Sufijo: een, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: told, Lema: tell, Sufijo: old, Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
# Token: for, Lema: for, Sufijo: for, Análisis Morfológico:
# Token: so, Lema: so, Sufijo: so, Análisis Morfológico:
# Token: long, Lema: long, Sufijo: ong, Análisis Morfológico:
# Token: by, Lema: by, Sufijo: by, Análisis Morfológico:
# Token: so, Lema: so, Sufijo: so, Análisis Morfológico:
# Token: many, Lema: many, Sufijo: any, Análisis Morfológico: Degree=Pos
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: be, Lema: be, Sufijo: be, Análisis Morfológico: VerbForm=Inf
# Token: cynical, Lema: cynical, Sufijo: cal, Análisis Morfológico: Degree=Pos
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: fearful, Lema: fearful, Sufijo: ful, Análisis Morfológico: Degree=Pos
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: doubtful, Lema: doubtful, Sufijo: ful, Análisis Morfológico: Degree=Pos
# Token: about, Lema: about, Sufijo: out, Análisis Morfológico:
# Token: what, Lema: what, Sufijo: hat, Análisis Morfológico:
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: can, Lema: can, Sufijo: can, Análisis Morfológico: VerbForm=Fin
# Token: achieve, Lema: achieve, Sufijo: eve, Análisis Morfológico: VerbForm=Inf
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: put, Lema: put, Sufijo: put, Análisis Morfológico: VerbForm=Inf
# Token: their, Lema: their, Sufijo: eir, Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# Token: hands, Lema: hand, Sufijo: nds, Análisis Morfológico: Number=Plur
# Token: on, Lema: on, Sufijo: on, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: arc, Lema: arc, Sufijo: arc, Análisis Morfológico: Number=Sing
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: history, Lema: history, Sufijo: ory, Análisis Morfológico: Number=Sing
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: bend, Lema: bend, Sufijo: end, Análisis Morfológico: VerbForm=Inf
# Token: it, Lema: it, Sufijo: it, Análisis Morfológico: Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# Token: once, Lema: once, Sufijo: nce, Análisis Morfológico: NumType=Mult
# Token: more, Lema: more, Sufijo: ore, Análisis Morfológico: Degree=Cmp
# Token: toward, Lema: toward, Sufijo: ard, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: hope, Lema: hope, Sufijo: ope, Análisis Morfológico: Number=Sing
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: a, Lema: a, Sufijo: a, Análisis Morfológico: Definite=Ind|PronType=Art
# Token: better, Lema: well, Sufijo: ter, Análisis Morfológico: Degree=Cmp
# Token: day, Lema: day, Sufijo: day, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: It, Lema: it, Sufijo: It, Análisis Morfológico: Gender=Neut|Number=Sing|Person=3|PronType=Prs
# Token: ’s, Lema: be, Sufijo: ’s, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: been, Lema: be, Sufijo: een, Análisis Morfológico: Tense=Past|VerbForm=Part
# Token: a, Lema: a, Sufijo: a, Análisis Morfológico: Definite=Ind|PronType=Art
# Token: long, Lema: long, Sufijo: ong, Análisis Morfológico: Degree=Pos
# Token: time, Lema: time, Sufijo: ime, Análisis Morfológico: Number=Sing
# Token: coming, Lema: come, Sufijo: ing, Análisis Morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: but, Lema: but, Sufijo: but, Análisis Morfológico: ConjType=Cmp
# Token: tonight, Lema: tonight, Sufijo: ght, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: because, Lema: because, Sufijo: use, Análisis Morfológico:
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: what, Lema: what, Sufijo: hat, Análisis Morfológico:
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: did, Lema: do, Sufijo: did, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: on, Lema: on, Sufijo: on, Análisis Morfológico:
# Token: this, Lema: this, Sufijo: his, Análisis Morfológico: Number=Sing|PronType=Dem
# Token: date, Lema: date, Sufijo: ate, Análisis Morfológico: Number=Sing
# Token: in, Lema: in, Sufijo: in, Análisis Morfológico:
# Token: this, Lema: this, Sufijo: his, Análisis Morfológico: Number=Sing|PronType=Dem
# Token: election, Lema: election, Sufijo: ion, Análisis Morfológico: Number=Sing
# Token: at, Lema: at, Sufijo: at, Análisis Morfológico:
# Token: this, Lema: this, Sufijo: his, Análisis Morfológico: Number=Sing|PronType=Dem
# Token: defining, Lema: define, Sufijo: ing, Análisis Morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
# Token: moment, Lema: moment, Sufijo: ent, Análisis Morfológico: Number=Sing
# Token: change, Lema: change, Sufijo: nge, Análisis Morfológico: Number=Sing
# Token: has, Lema: have, Sufijo: has, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: come, Lema: come, Sufijo: ome, Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: America, Lema: America, Sufijo: ica, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: [, Lema: [, Sufijo: [, Análisis Morfológico: PunctSide=Ini|PunctType=Brck
# Token: read, Lema: read, Sufijo: ead, Análisis Morfológico: VerbForm=Inf
# Token: more, Lema: more, Sufijo: ore, Análisis Morfológico: Degree=Cmp
# Token: ], Lema: ], Sufijo: ], Análisis Morfológico: PunctSide=Fin|PunctType=Brck
# Token:
#
# , Lema:
#
# , Sufijo:
#
# , Análisis Morfológico:
# Token: We, Lema: we, Sufijo: We, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: did, Lema: did, Sufijo: did, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: n’t, Lema: n’t, Sufijo: n’t, Análisis Morfológico: Polarity=Neg
# Token: start, Lema: start, Sufijo: art, Análisis Morfológico: VerbForm=Inf
# Token: with, Lema: with, Sufijo: ith, Análisis Morfológico:
# Token: much, Lema: much, Sufijo: uch, Análisis Morfológico: Degree=Pos
# Token: money, Lema: money, Sufijo: ney, Análisis Morfológico: Number=Sing
# Token: or, Lema: or, Sufijo: or, Análisis Morfológico: ConjType=Cmp
# Token: many, Lema: many, Sufijo: any, Análisis Morfológico: Degree=Pos
# Token: endorsements, Lema: endorsement, Sufijo: nts, Análisis Morfológico: Number=Plur
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token: Our, Lema: our, Sufijo: Our, Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# Token: campaign, Lema: campaign, Sufijo: ign, Análisis Morfológico: Number=Sing
# Token: was, Lema: be, Sufijo: was, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# Token: not, Lema: not, Sufijo: not, Análisis Morfológico: Polarity=Neg
# Token: hatched, Lema: hatch, Sufijo: hed, Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
# Token: in, Lema: in, Sufijo: in, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: halls, Lema: hall, Sufijo: lls, Análisis Morfológico: Number=Plur
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: Washington, Lema: Washington, Sufijo: ton, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token: It, Lema: it, Sufijo: It, Análisis Morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# Token: began, Lema: begin, Sufijo: gan, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: in, Lema: in, Sufijo: in, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: backyards, Lema: backyard, Sufijo: rds, Análisis Morfológico: Number=Plur
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: Des, Lema: Des, Sufijo: Des, Análisis Morfológico: Number=Sing
# Token: Moines, Lema: Moines, Sufijo: nes, Análisis Morfológico: Number=Sing
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: living, Lema: live, Sufijo: ing, Análisis Morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
# Token: rooms, Lema: room, Sufijo: oms, Análisis Morfológico: Number=Plur
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: Concord, Lema: Concord, Sufijo: ord, Análisis Morfológico: Number=Sing
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: front, Lema: front, Sufijo: ont, Análisis Morfológico: Degree=Pos
# Token: porches, Lema: porch, Sufijo: hes, Análisis Morfológico: Number=Plur
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: Charleston, Lema: Charleston, Sufijo: ton, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token: It, Lema: it, Sufijo: It, Análisis Morfológico: Gender=Neut|Number=Sing|Person=3|PronType=Prs
# Token: was, Lema: be, Sufijo: was, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# Token: built, Lema: build, Sufijo: ilt, Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
# Token: by, Lema: by, Sufijo: by, Análisis Morfológico:
# Token: working, Lema: work, Sufijo: ing, Análisis Morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
# Token: men, Lema: man, Sufijo: men, Análisis Morfológico: Number=Plur
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: women, Lema: woman, Sufijo: men, Análisis Morfológico: Number=Plur
# Token: who, Lema: who, Sufijo: who, Análisis Morfológico:
# Token: dug, Lema: dig, Sufijo: dug, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: into, Lema: into, Sufijo: nto, Análisis Morfológico:
# Token: what, Lema: what, Sufijo: hat, Análisis Morfológico:
# Token: little, Lema: little, Sufijo: tle, Análisis Morfológico: Degree=Pos
# Token: savings, Lema: saving, Sufijo: ngs, Análisis Morfológico: Number=Plur
# Token: they, Lema: they, Sufijo: hey, Análisis Morfológico: Case=Nom|Number=Plur|Person=3|PronType=Prs
# Token: had, Lema: have, Sufijo: had, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: give, Lema: give, Sufijo: ive, Análisis Morfológico: VerbForm=Inf
# Token: $, Lema: $, Sufijo: $, Análisis Morfológico:
# Token: 5, Lema: 5, Sufijo: 5, Análisis Morfológico: NumType=Card
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: $, Lema: $, Sufijo: $, Análisis Morfológico:
# Token: 10, Lema: 10, Sufijo: 10, Análisis Morfológico: NumType=Card
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: $, Lema: $, Sufijo: $, Análisis Morfológico:
# Token: 20, Lema: 20, Sufijo: 20, Análisis Morfológico: NumType=Card
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: cause, Lema: cause, Sufijo: use, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: It, Lema: it, Sufijo: It, Análisis Morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# Token: grew, Lema: grow, Sufijo: rew, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: strength, Lema: strength, Sufijo: gth, Análisis Morfológico: Number=Sing
# Token: from, Lema: from, Sufijo: rom, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: young, Lema: young, Sufijo: ung, Análisis Morfológico: Degree=Pos
# Token: people, Lema: people, Sufijo: ple, Análisis Morfológico: Number=Plur
# Token: who, Lema: who, Sufijo: who, Análisis Morfológico:
# Token: rejected, Lema: reject, Sufijo: ted, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: myth, Lema: myth, Sufijo: yth, Análisis Morfológico: Number=Sing
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: their, Lema: their, Sufijo: eir, Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# Token: generation, Lema: generation, Sufijo: ion, Análisis Morfológico: Number=Sing
# Token: ’s, Lema: ’s, Sufijo: ’s, Análisis Morfológico:
# Token: apathy, Lema: apathy, Sufijo: thy, Análisis Morfológico: Degree=Pos
# Token: who, Lema: who, Sufijo: who, Análisis Morfológico:
# Token: left, Lema: leave, Sufijo: eft, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: their, Lema: their, Sufijo: eir, Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# Token: homes, Lema: home, Sufijo: mes, Análisis Morfológico: Number=Plur
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: their, Lema: their, Sufijo: eir, Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# Token: families, Lema: family, Sufijo: ies, Análisis Morfológico: Number=Plur
# Token: for, Lema: for, Sufijo: for, Análisis Morfológico:
# Token: jobs, Lema: job, Sufijo: obs, Análisis Morfológico: Number=Plur
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico: PronType=Rel
# Token: offered, Lema: offer, Sufijo: red, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: little, Lema: little, Sufijo: tle, Análisis Morfológico: Degree=Pos
# Token: pay, Lema: pay, Sufijo: pay, Análisis Morfológico: Number=Sing
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: less, Lema: less, Sufijo: ess, Análisis Morfológico: Degree=Cmp
# Token: sleep, Lema: sleep, Sufijo: eep, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: It, Lema: it, Sufijo: It, Análisis Morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# Token: drew, Lema: draw, Sufijo: rew, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: strength, Lema: strength, Sufijo: gth, Análisis Morfológico: Number=Sing
# Token: from, Lema: from, Sufijo: rom, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: not, Lema: not, Sufijo: not, Análisis Morfológico: Polarity=Neg
# Token: -, Lema: -, Sufijo: -, Análisis Morfológico: PunctType=Dash
# Token: so, Lema: so, Sufijo: so, Análisis Morfológico:
# Token: -, Lema: -, Sufijo: -, Análisis Morfológico: PunctType=Dash
# Token: young, Lema: young, Sufijo: ung, Análisis Morfológico: Degree=Pos
# Token: people, Lema: people, Sufijo: ple, Análisis Morfológico: Number=Plur
# Token: who, Lema: who, Sufijo: who, Análisis Morfológico:
# Token: braved, Lema: brave, Sufijo: ved, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: bitter, Lema: bitter, Sufijo: ter, Análisis Morfológico: Degree=Pos
# Token: cold, Lema: cold, Sufijo: old, Análisis Morfológico: Number=Sing
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: scorching, Lema: scorch, Sufijo: ing, Análisis Morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
# Token: heat, Lema: heat, Sufijo: eat, Análisis Morfológico: Number=Sing
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: knock, Lema: knock, Sufijo: ock, Análisis Morfológico: VerbForm=Inf
# Token: on, Lema: on, Sufijo: on, Análisis Morfológico:
# Token: doors, Lema: door, Sufijo: ors, Análisis Morfológico: Number=Plur
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: perfect, Lema: perfect, Sufijo: ect, Análisis Morfológico: Degree=Pos
# Token: strangers, Lema: stranger, Sufijo: ers, Análisis Morfológico: Number=Plur
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: from, Lema: from, Sufijo: rom, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: millions, Lema: million, Sufijo: ons, Análisis Morfológico: Number=Plur
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: Americans, Lema: Americans, Sufijo: ans, Análisis Morfológico: Number=Plur
# Token: who, Lema: who, Sufijo: who, Análisis Morfológico:
# Token: volunteered, Lema: volunteer, Sufijo: red, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: organized, Lema: organize, Sufijo: zed, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: proved, Lema: prove, Sufijo: ved, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico:
# Token: more, Lema: more, Sufijo: ore, Análisis Morfológico: Degree=Cmp
# Token: than, Lema: than, Sufijo: han, Análisis Morfológico:
# Token: two, Lema: two, Sufijo: two, Análisis Morfológico: NumType=Card
# Token: centuries, Lema: century, Sufijo: ies, Análisis Morfológico: Number=Plur
# Token: later, Lema: later, Sufijo: ter, Análisis Morfológico:
# Token: a, Lema: a, Sufijo: a, Análisis Morfológico: Definite=Ind|PronType=Art
# Token: government, Lema: government, Sufijo: ent, Análisis Morfológico: Number=Sing
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: people, Lema: people, Sufijo: ple, Análisis Morfológico: Number=Plur
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: by, Lema: by, Sufijo: by, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: people, Lema: people, Sufijo: ple, Análisis Morfológico: Number=Plur
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: for, Lema: for, Sufijo: for, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: people, Lema: people, Sufijo: ple, Análisis Morfológico: Number=Plur
# Token: has, Lema: have, Sufijo: has, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: not, Lema: not, Sufijo: not, Análisis Morfológico: Polarity=Neg
# Token: perished, Lema: perish, Sufijo: hed, Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
# Token: from, Lema: from, Sufijo: rom, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: Earth, Lema: Earth, Sufijo: rth, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: This, Lema: this, Sufijo: his, Análisis Morfológico: Number=Sing|PronType=Dem
# Token: is, Lema: be, Sufijo: is, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: your, Lema: your, Sufijo: our, Análisis Morfológico: Person=2|Poss=Yes|PronType=Prs
# Token: victory, Lema: victory, Sufijo: ory, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: And, Lema: and, Sufijo: And, Análisis Morfológico: ConjType=Cmp
# Token: I, Lema: I, Sufijo: I, Análisis Morfológico: Case=Nom|Number=Sing|Person=1|PronType=Prs
# Token: know, Lema: know, Sufijo: now, Análisis Morfológico: Tense=Pres|VerbForm=Fin
# Token: you, Lema: you, Sufijo: you, Análisis Morfológico: Case=Nom|Person=2|PronType=Prs
# Token: did, Lema: did, Sufijo: did, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: n’t, Lema: n’t, Sufijo: n’t, Análisis Morfológico: Polarity=Neg
# Token: do, Lema: do, Sufijo: do, Análisis Morfológico: VerbForm=Inf
# Token: this, Lema: this, Sufijo: his, Análisis Morfológico: Number=Sing|PronType=Dem
# Token: just, Lema: just, Sufijo: ust, Análisis Morfológico:
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: win, Lema: win, Sufijo: win, Análisis Morfológico: VerbForm=Inf
# Token: an, Lema: an, Sufijo: an, Análisis Morfológico: Definite=Ind|PronType=Art
# Token: election, Lema: election, Sufijo: ion, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token: And, Lema: and, Sufijo: And, Análisis Morfológico: ConjType=Cmp
# Token: I, Lema: I, Sufijo: I, Análisis Morfológico: Case=Nom|Number=Sing|Person=1|PronType=Prs
# Token: know, Lema: know, Sufijo: now, Análisis Morfológico: Tense=Pres|VerbForm=Fin
# Token: you, Lema: you, Sufijo: you, Análisis Morfológico: Case=Nom|Person=2|PronType=Prs
# Token: did, Lema: did, Sufijo: did, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: n’t, Lema: n’t, Sufijo: n’t, Análisis Morfológico: Polarity=Neg
# Token: do, Lema: do, Sufijo: do, Análisis Morfológico: VerbForm=Inf
# Token: it, Lema: it, Sufijo: it, Análisis Morfológico: Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# Token: for, Lema: for, Sufijo: for, Análisis Morfológico:
# Token: me, Lema: I, Sufijo: me, Análisis Morfológico: Case=Acc|Number=Sing|Person=1|PronType=Prs
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: You, Lema: you, Sufijo: You, Análisis Morfológico: Case=Nom|Person=2|PronType=Prs
# Token: did, Lema: do, Sufijo: did, Análisis Morfológico: Tense=Past|VerbForm=Fin
# Token: it, Lema: it, Sufijo: it, Análisis Morfológico: Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# Token: because, Lema: because, Sufijo: use, Análisis Morfológico:
# Token: you, Lema: you, Sufijo: you, Análisis Morfológico: Case=Nom|Person=2|PronType=Prs
# Token: understand, Lema: understand, Sufijo: and, Análisis Morfológico: Tense=Pres|VerbForm=Fin
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: enormity, Lema: enormity, Sufijo: ity, Análisis Morfológico: Number=Sing
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: task, Lema: task, Sufijo: ask, Análisis Morfológico: Number=Sing
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico: PronType=Rel
# Token: lies, Lema: lie, Sufijo: ies, Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: ahead, Lema: ahead, Sufijo: ead, Análisis Morfológico:
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token: For, Lema: for, Sufijo: For, Análisis Morfológico:
# Token: even, Lema: even, Sufijo: ven, Análisis Morfológico:
# Token: as, Lema: as, Sufijo: as, Análisis Morfológico:
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: celebrate, Lema: celebrate, Sufijo: ate, Análisis Morfológico: Tense=Pres|VerbForm=Fin
# Token: tonight, Lema: tonight, Sufijo: ght, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: know, Lema: know, Sufijo: now, Análisis Morfológico: Tense=Pres|VerbForm=Fin
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: challenges, Lema: challenge, Sufijo: ges, Análisis Morfológico: Number=Plur
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico: PronType=Rel
# Token: tomorrow, Lema: tomorrow, Sufijo: row, Análisis Morfológico: Number=Sing
# Token: will, Lema: will, Sufijo: ill, Análisis Morfológico: VerbForm=Fin
# Token: bring, Lema: bring, Sufijo: ing, Análisis Morfológico: VerbForm=Inf
# Token: are, Lema: be, Sufijo: are, Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: greatest, Lema: great, Sufijo: est, Análisis Morfológico: Degree=Sup
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: our, Lema: our, Sufijo: our, Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# Token: lifetime, Lema: lifetime, Sufijo: ime, Análisis Morfológico: Number=Sing
# Token: —, Lema: —, Sufijo: —, Análisis Morfológico:
# Token: two, Lema: two, Sufijo: two, Análisis Morfológico: NumType=Card
# Token: wars, Lema: war, Sufijo: ars, Análisis Morfológico: Number=Plur
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: a, Lema: a, Sufijo: a, Análisis Morfológico: Definite=Ind|PronType=Art
# Token: planet, Lema: planet, Sufijo: net, Análisis Morfológico: Number=Sing
# Token: in, Lema: in, Sufijo: in, Análisis Morfológico:
# Token: peril, Lema: peril, Sufijo: ril, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: worst, Lema: bad, Sufijo: rst, Análisis Morfológico: Degree=Sup
# Token: financial, Lema: financial, Sufijo: ial, Análisis Morfológico: Degree=Pos
# Token: crisis, Lema: crisis, Sufijo: sis, Análisis Morfológico: Number=Sing
# Token: in, Lema: in, Sufijo: in, Análisis Morfológico:
# Token: a, Lema: a, Sufijo: a, Análisis Morfológico: Definite=Ind|PronType=Art
# Token: century, Lema: century, Sufijo: ury, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: Even, Lema: even, Sufijo: ven, Análisis Morfológico:
# Token: as, Lema: as, Sufijo: as, Análisis Morfológico:
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: stand, Lema: stand, Sufijo: and, Análisis Morfológico: Tense=Pres|VerbForm=Fin
# Token: here, Lema: here, Sufijo: ere, Análisis Morfológico: PronType=Dem
# Token: tonight, Lema: tonight, Sufijo: ght, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: know, Lema: know, Sufijo: now, Análisis Morfológico: Tense=Pres|VerbForm=Fin
# Token: there, Lema: there, Sufijo: ere, Análisis Morfológico:
# Token: are, Lema: be, Sufijo: are, Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
# Token: brave, Lema: brave, Sufijo: ave, Análisis Morfológico: Degree=Pos
# Token: Americans, Lema: Americans, Sufijo: ans, Análisis Morfológico: Number=Plur
# Token: waking, Lema: wake, Sufijo: ing, Análisis Morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
# Token: up, Lema: up, Sufijo: up, Análisis Morfológico:
# Token: in, Lema: in, Sufijo: in, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: deserts, Lema: desert, Sufijo: rts, Análisis Morfológico: Number=Plur
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: Iraq, Lema: Iraq, Sufijo: raq, Análisis Morfológico: Number=Sing
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: mountains, Lema: mountain, Sufijo: ins, Análisis Morfológico: Number=Plur
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: Afghanistan, Lema: Afghanistan, Sufijo: tan, Análisis Morfológico: Number=Sing
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: risk, Lema: risk, Sufijo: isk, Análisis Morfológico: VerbForm=Inf
# Token: their, Lema: their, Sufijo: eir, Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# Token: lives, Lema: life, Sufijo: ves, Análisis Morfológico: Number=Plur
# Token: for, Lema: for, Sufijo: for, Análisis Morfológico:
# Token: us, Lema: we, Sufijo: us, Análisis Morfológico: Case=Acc|Number=Plur|Person=1|PronType=Prs
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: There, Lema: there, Sufijo: ere, Análisis Morfológico:
# Token: are, Lema: be, Sufijo: are, Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
# Token: mothers, Lema: mother, Sufijo: ers, Análisis Morfológico: Number=Plur
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: fathers, Lema: father, Sufijo: ers, Análisis Morfológico: Number=Plur
# Token: who, Lema: who, Sufijo: who, Análisis Morfológico:
# Token: will, Lema: will, Sufijo: ill, Análisis Morfológico: VerbForm=Fin
# Token: lie, Lema: lie, Sufijo: lie, Análisis Morfológico: VerbForm=Inf
# Token: awake, Lema: awake, Sufijo: ake, Análisis Morfológico: Degree=Pos
# Token: after, Lema: after, Sufijo: ter, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: children, Lema: child, Sufijo: ren, Análisis Morfológico: Number=Plur
# Token: fall, Lema: fall, Sufijo: all, Análisis Morfológico: Tense=Pres|VerbForm=Fin
# Token: asleep, Lema: asleep, Sufijo: eep, Análisis Morfológico: Degree=Pos
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: wonder, Lema: wonder, Sufijo: der, Análisis Morfológico: Tense=Pres|VerbForm=Fin
# Token: how, Lema: how, Sufijo: how, Análisis Morfológico:
# Token: they, Lema: they, Sufijo: hey, Análisis Morfológico: Case=Nom|Number=Plur|Person=3|PronType=Prs
# Token: ’ll, Lema: ’ll, Sufijo: ’ll, Análisis Morfológico: VerbForm=Fin
# Token: make, Lema: make, Sufijo: ake, Análisis Morfológico: VerbForm=Inf
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: mortgage, Lema: mortgage, Sufijo: age, Análisis Morfológico: Number=Sing
# Token: or, Lema: or, Sufijo: or, Análisis Morfológico: ConjType=Cmp
# Token: pay, Lema: pay, Sufijo: pay, Análisis Morfológico: VerbForm=Inf
# Token: their, Lema: their, Sufijo: eir, Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# Token: doctors, Lema: doctor, Sufijo: ors, Análisis Morfológico: Number=Plur
# Token: ’, Lema: ’, Sufijo: ’, Análisis Morfológico:
# Token: bills, Lema: bill, Sufijo: lls, Análisis Morfológico: Number=Plur
# Token: or, Lema: or, Sufijo: or, Análisis Morfológico: ConjType=Cmp
# Token: save, Lema: save, Sufijo: ave, Análisis Morfológico: VerbForm=Inf
# Token: enough, Lema: enough, Sufijo: ugh, Análisis Morfológico: Degree=Pos
# Token: for, Lema: for, Sufijo: for, Análisis Morfológico:
# Token: their, Lema: their, Sufijo: eir, Análisis Morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# Token: child, Lema: child, Sufijo: ild, Análisis Morfológico: Number=Sing
# Token: ’s, Lema: ’s, Sufijo: ’s, Análisis Morfológico:
# Token: college, Lema: college, Sufijo: ege, Análisis Morfológico: Number=Sing
# Token: education, Lema: education, Sufijo: ion, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: There, Lema: there, Sufijo: ere, Análisis Morfológico:
# Token: ’s, Lema: be, Sufijo: ’s, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: new, Lema: new, Sufijo: new, Análisis Morfológico: Degree=Pos
# Token: energy, Lema: energy, Sufijo: rgy, Análisis Morfológico: Number=Sing
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: harness, Lema: harness, Sufijo: ess, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: new, Lema: new, Sufijo: new, Análisis Morfológico: Degree=Pos
# Token: jobs, Lema: job, Sufijo: obs, Análisis Morfológico: Number=Plur
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: be, Lema: be, Sufijo: be, Análisis Morfológico: VerbForm=Inf
# Token: created, Lema: create, Sufijo: ted, Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: new, Lema: new, Sufijo: new, Análisis Morfológico: Degree=Pos
# Token: schools, Lema: school, Sufijo: ols, Análisis Morfológico: Number=Plur
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: build, Lema: build, Sufijo: ild, Análisis Morfológico: VerbForm=Inf
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# ...
# Token: in, Lema: in, Sufijo: in, Análisis Morfológico:
# Token: America, Lema: America, Sufijo: ica, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: through, Lema: through, Sufijo: ugh, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: best, Lema: good, Sufijo: est, Análisis Morfológico: Degree=Sup
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: times, Lema: time, Sufijo: mes, Análisis Morfológico: Number=Plur
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: darkest, Lema: darkest, Sufijo: est, Análisis Morfológico: Number=Sing
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: hours, Lema: hour, Sufijo: urs, Análisis Morfológico: Number=Plur
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: she, Lema: she, Sufijo: she, Análisis Morfológico: Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs
# Token: knows, Lema: know, Sufijo: ows, Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: how, Lema: how, Sufijo: how, Análisis Morfológico:
# Token: America, Lema: America, Sufijo: ica, Análisis Morfológico: Number=Sing
# Token: can, Lema: can, Sufijo: can, Análisis Morfológico: VerbForm=Fin
# Token: change, Lema: change, Sufijo: nge, Análisis Morfológico: VerbForm=Inf
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: Yes, Lema: yes, Sufijo: Yes, Análisis Morfológico:
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: can, Lema: can, Sufijo: can, Análisis Morfológico: VerbForm=Fin
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: America, Lema: America, Sufijo: ica, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: have, Lema: have, Sufijo: ave, Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
# Token: come, Lema: come, Sufijo: ome, Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
# Token: so, Lema: so, Sufijo: so, Análisis Morfológico:
# Token: far, Lema: far, Sufijo: far, Análisis Morfológico:
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token: We, Lema: we, Sufijo: We, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: have, Lema: have, Sufijo: ave, Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
# Token: seen, Lema: see, Sufijo: een, Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
# Token: so, Lema: so, Sufijo: so, Análisis Morfológico:
# Token: much, Lema: much, Sufijo: uch, Análisis Morfológico: Degree=Pos
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token: But, Lema: but, Sufijo: But, Análisis Morfológico: ConjType=Cmp
# Token: there, Lema: there, Sufijo: ere, Análisis Morfológico:
# Token: is, Lema: be, Sufijo: is, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: so, Lema: so, Sufijo: so, Análisis Morfológico:
# Token: much, Lema: much, Sufijo: uch, Análisis Morfológico:
# Token: more, Lema: more, Sufijo: ore, Análisis Morfológico: Degree=Cmp
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: do, Lema: do, Sufijo: do, Análisis Morfológico: VerbForm=Inf
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token: So, Lema: so, Sufijo: So, Análisis Morfológico:
# Token: tonight, Lema: tonight, Sufijo: ght, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: let, Lema: let, Sufijo: let, Análisis Morfológico: VerbForm=Inf
# Token: us, Lema: we, Sufijo: us, Análisis Morfológico: Case=Acc|Number=Plur|Person=1|PronType=Prs
# Token: ask, Lema: ask, Sufijo: ask, Análisis Morfológico: VerbForm=Inf
# Token: ourselves, Lema: ourselves, Sufijo: ves, Análisis Morfológico: Case=Acc|Number=Plur|Person=1|PronType=Prs|Reflex=Yes
# Token: —, Lema: —, Sufijo: —, Análisis Morfológico:
# Token: if, Lema: if, Sufijo: if, Análisis Morfológico:
# Token: our, Lema: our, Sufijo: our, Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# Token: children, Lema: child, Sufijo: ren, Análisis Morfológico: Number=Plur
# Token: should, Lema: should, Sufijo: uld, Análisis Morfológico: VerbForm=Fin
# Token: live, Lema: live, Sufijo: ive, Análisis Morfológico: VerbForm=Inf
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: see, Lema: see, Sufijo: see, Análisis Morfológico: VerbForm=Inf
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: next, Lema: next, Sufijo: ext, Análisis Morfológico: Degree=Pos
# Token: century, Lema: century, Sufijo: ury, Análisis Morfológico: Number=Sing
# Token: ;, Lema: ;, Sufijo: ;, Análisis Morfológico:
# Token: if, Lema: if, Sufijo: if, Análisis Morfológico:
# Token: my, Lema: my, Sufijo: my, Análisis Morfológico: Number=Sing|Person=1|Poss=Yes|PronType=Prs
# Token: daughters, Lema: daughter, Sufijo: ers, Análisis Morfológico: Number=Plur
# Token: should, Lema: should, Sufijo: uld, Análisis Morfológico: VerbForm=Fin
# Token: be, Lema: be, Sufijo: be, Análisis Morfológico: VerbForm=Inf
# Token: so, Lema: so, Sufijo: so, Análisis Morfológico:
# Token: lucky, Lema: lucky, Sufijo: cky, Análisis Morfológico: Degree=Pos
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: live, Lema: live, Sufijo: ive, Análisis Morfológico: VerbForm=Inf
# Token: as, Lema: as, Sufijo: as, Análisis Morfológico:
# Token: long, Lema: long, Sufijo: ong, Análisis Morfológico:
# Token: as, Lema: as, Sufijo: as, Análisis Morfológico:
# Token: Ann, Lema: Ann, Sufijo: Ann, Análisis Morfológico: Number=Sing
# Token: Nixon, Lema: Nixon, Sufijo: xon, Análisis Morfológico: Number=Sing
# Token: Cooper, Lema: Cooper, Sufijo: per, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: what, Lema: what, Sufijo: hat, Análisis Morfológico:
# Token: change, Lema: change, Sufijo: nge, Análisis Morfológico: Number=Sing
# Token: will, Lema: will, Sufijo: ill, Análisis Morfológico: VerbForm=Fin
# Token: they, Lema: they, Sufijo: hey, Análisis Morfológico: Case=Nom|Number=Plur|Person=3|PronType=Prs
# Token: see, Lema: see, Sufijo: see, Análisis Morfológico: VerbForm=Inf
# Token: ?, Lema: ?, Sufijo: ?, Análisis Morfológico: PunctType=Peri
# Token: What, Lema: what, Sufijo: hat, Análisis Morfológico:
# Token: progress, Lema: progress, Sufijo: ess, Análisis Morfológico: Number=Sing
# Token: will, Lema: will, Sufijo: ill, Análisis Morfológico: VerbForm=Fin
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: have, Lema: have, Sufijo: ave, Análisis Morfológico: VerbForm=Inf
# Token: made, Lema: make, Sufijo: ade, Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
# Token: ?, Lema: ?, Sufijo: ?, Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: This, Lema: this, Sufijo: his, Análisis Morfológico: Number=Sing|PronType=Dem
# Token: is, Lema: be, Sufijo: is, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: our, Lema: our, Sufijo: our, Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# Token: chance, Lema: chance, Sufijo: nce, Análisis Morfológico: Number=Sing
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: answer, Lema: answer, Sufijo: wer, Análisis Morfológico: VerbForm=Inf
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico: Number=Sing|PronType=Dem
# Token: call, Lema: call, Sufijo: all, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token: This, Lema: this, Sufijo: his, Análisis Morfológico: Number=Sing|PronType=Dem
# Token: is, Lema: be, Sufijo: is, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: our, Lema: our, Sufijo: our, Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# Token: moment, Lema: moment, Sufijo: ent, Análisis Morfológico: Number=Sing
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token:
# , Lema:
# , Sufijo:
# , Análisis Morfológico:
# Token: This, Lema: this, Sufijo: his, Análisis Morfológico: Number=Sing|PronType=Dem
# Token: is, Lema: be, Sufijo: is, Análisis Morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: our, Lema: our, Sufijo: our, Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# Token: time, Lema: time, Sufijo: ime, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: put, Lema: put, Sufijo: put, Análisis Morfológico: VerbForm=Inf
# Token: our, Lema: our, Sufijo: our, Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# Token: people, Lema: people, Sufijo: ple, Análisis Morfológico: Number=Plur
# Token: back, Lema: back, Sufijo: ack, Análisis Morfológico:
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: work, Lema: work, Sufijo: ork, Análisis Morfológico: Number=Sing
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: open, Lema: open, Sufijo: pen, Análisis Morfológico: Degree=Pos
# Token: doors, Lema: door, Sufijo: ors, Análisis Morfológico: Number=Plur
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: opportunity, Lema: opportunity, Sufijo: ity, Análisis Morfológico: Number=Sing
# Token: for, Lema: for, Sufijo: for, Análisis Morfológico:
# Token: our, Lema: our, Sufijo: our, Análisis Morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# Token: kids, Lema: kid, Sufijo: ids, Análisis Morfológico: Number=Plur
# Token: ;, Lema: ;, Sufijo: ;, Análisis Morfológico:
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: restore, Lema: restore, Sufijo: ore, Análisis Morfológico: VerbForm=Inf
# Token: prosperity, Lema: prosperity, Sufijo: ity, Análisis Morfológico: Number=Sing
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: promote, Lema: promote, Sufijo: ote, Análisis Morfológico: VerbForm=Inf
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: cause, Lema: cause, Sufijo: use, Análisis Morfológico: Number=Sing
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: peace, Lema: peace, Sufijo: ace, Análisis Morfológico: Number=Sing
# Token: ;, Lema: ;, Sufijo: ;, Análisis Morfológico:
# Token: to, Lema: to, Sufijo: to, Análisis Morfológico:
# Token: reclaim, Lema: reclaim, Sufijo: aim, Análisis Morfológico: VerbForm=Inf
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: American, Lema: american, Sufijo: can, Análisis Morfológico: Degree=Pos
# Token: dream, Lema: dream, Sufijo: eam, Análisis Morfológico: Number=Sing
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: reaffirm, Lema: reaffirm, Sufijo: irm, Análisis Morfológico: VerbForm=Inf
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico: Number=Sing|PronType=Dem
# Token: fundamental, Lema: fundamental, Sufijo: tal, Análisis Morfológico: Degree=Pos
# Token: truth, Lema: truth, Sufijo: uth, Análisis Morfológico: Number=Sing
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico:
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: out, Lema: out, Sufijo: out, Análisis Morfológico:
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: many, Lema: many, Sufijo: any, Análisis Morfológico: Degree=Pos
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: are, Lema: be, Sufijo: are, Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
# Token: one, Lema: one, Sufijo: one, Análisis Morfológico: NumType=Card
# Token: ;, Lema: ;, Sufijo: ;, Análisis Morfológico:
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico:
# Token: while, Lema: while, Sufijo: ile, Análisis Morfológico:
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: breathe, Lema: breathe, Sufijo: the, Análisis Morfológico: Tense=Pres|VerbForm=Fin
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: hope, Lema: hope, Sufijo: ope, Análisis Morfológico: Tense=Pres|VerbForm=Fin
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token: And, Lema: and, Sufijo: And, Análisis Morfológico: ConjType=Cmp
# Token: where, Lema: where, Sufijo: ere, Análisis Morfológico:
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: are, Lema: be, Sufijo: are, Análisis Morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
# Token: met, Lema: meet, Sufijo: met, Análisis Morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
# Token: with, Lema: with, Sufijo: ith, Análisis Morfológico:
# Token: cynicism, Lema: cynicism, Sufijo: ism, Análisis Morfológico: Number=Sing
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: doubts, Lema: doubt, Sufijo: bts, Análisis Morfológico: Number=Plur
# Token: and, Lema: and, Sufijo: and, Análisis Morfológico: ConjType=Cmp
# Token: those, Lema: those, Sufijo: ose, Análisis Morfológico: Number=Plur|PronType=Dem
# Token: who, Lema: who, Sufijo: who, Análisis Morfológico:
# Token: tell, Lema: tell, Sufijo: ell, Análisis Morfológico: Tense=Pres|VerbForm=Fin
# Token: us, Lema: we, Sufijo: us, Análisis Morfológico: Case=Acc|Number=Plur|Person=1|PronType=Prs
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico:
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: ca, Lema: ca, Sufijo: ca, Análisis Morfológico: VerbForm=Fin
# Token: n’t, Lema: n’t, Sufijo: n’t, Análisis Morfológico: Polarity=Neg
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: will, Lema: will, Sufijo: ill, Análisis Morfológico: VerbForm=Fin
# Token: respond, Lema: respond, Sufijo: ond, Análisis Morfológico: VerbForm=Inf
# Token: with, Lema: with, Sufijo: ith, Análisis Morfológico:
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico: Number=Sing|PronType=Dem
# Token: timeless, Lema: timeless, Sufijo: ess, Análisis Morfológico: Number=Sing
# Token: creed, Lema: creed, Sufijo: eed, Análisis Morfológico: Number=Sing
# Token: that, Lema: that, Sufijo: hat, Análisis Morfológico: PronType=Rel
# Token: sums, Lema: sum, Sufijo: ums, Análisis Morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# Token: up, Lema: up, Sufijo: up, Análisis Morfológico:
# Token: the, Lema: the, Sufijo: the, Análisis Morfológico: Definite=Def|PronType=Art
# Token: spirit, Lema: spirit, Sufijo: rit, Análisis Morfológico: Number=Sing
# Token: of, Lema: of, Sufijo: of, Análisis Morfológico:
# Token: a, Lema: a, Sufijo: a, Análisis Morfológico: Definite=Ind|PronType=Art
# Token: people, Lema: people, Sufijo: ple, Análisis Morfológico: Number=Plur
# Token: :, Lema: :, Sufijo: :, Análisis Morfológico:
# Token: Yes, Lema: yes, Sufijo: Yes, Análisis Morfológico:
# Token: ,, Lema: ,, Sufijo: ,, Análisis Morfológico: PunctType=Comm
# Token: we, Lema: we, Sufijo: we, Análisis Morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
# Token: can, Lema: can, Sufijo: can, Análisis Morfológico: VerbForm=Fin
# Token: ., Lema: ., Sufijo: ., Análisis Morfológico: PunctType=Peri
# Token: [, Lema: [, Sufijo: [, Análisis Morfológico:

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# </br> * Para este punto se itera a traves de los token y con los atributos de 'lemma_', 'suffix_', 'morph' se obtienen los valores de cada token
# <hr>

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 5.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cómo puedes identificar/eliminar las stop words?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
# Filtrando palabras que no son stop words.
fitro = [token.text for token in doc if not token.is_stop]
#len(filtro)
# Unificando palabras filtradas en  nuevo texto.
texto_sin_stop_words = ''.join(fitro)

# Imprimiento el texto sin stop words.
#len(texto_sin_stop_words)
print(texto_sin_stop_words)
# Out:
# “Hello,Chicago.
# doubtsAmericaplacethingspossible,wondersdreamfoundersalivetime,questionspowerdemocracy,tonightanswer.
# answertoldlinesstretchedschoolschurchesnumbersnationseen,peoplewaitedhourshours,timelives,believedtimedifferent,voicesdifference.
# answerspokenyoungold,richpoor,DemocratRepublican,black,white,Hispanic,Asian,NativeAmerican,gay,straight,disableddisabled.Americanssentmessageworldcollectionindividualscollectionredstatesbluestates.
# ,,UnitedStatesAmerica.
# answerledtoldlongcynicalfearfuldoubtfulachievehandsarchistorybendhopebetterday.
# longtimecoming,tonight,dateelectiondefiningmomentchangecomeAmerica.
# [read]
#
# startmoneyendorsements.campaignhatchedhallsWashington.beganbackyardsDesMoineslivingroomsConcordporchesCharleston.builtworkingmenwomenduglittlesavings$5$10$20cause.
# grewstrengthyoungpeoplerejectedmythgenerationapathylefthomesfamiliesjobsofferedlittlepaysleep.
# drewstrength--youngpeoplebravedbittercoldscorchingheatknockdoorsperfectstrangers,millionsAmericansvolunteeredorganizedprovedcenturieslatergovernmentpeople,people,peopleperishedEarth.
# victory.
# knowwinelection.know.
# understandenormitytaskliesahead.celebratetonight,knowchallengestomorrowbringgreatestlifetime—wars,planetperil,worstfinancialcrisiscentury.
# standtonight,knowbraveAmericanswakingdesertsIraqmountainsAfghanistanrisklives.
# mothersfatherslieawakechildrenfallasleepwondermortgagepaydoctors’billssavechildcollegeeducation.
# newenergyharness,newjobscreated,newschoolsbuild,threatsmeet,alliancesrepair.
# roadaheadlong.climbsteep.yearterm.,America,hopefultonight.
# promise,people.
# setbacksfalsestarts.woagreedecisionpolicypresident.knowgovernmentsolveproblem.
# honestchallengesface.listen,especiallydisagree.,,askjoinworkremakingnation,wayAmerica221years—blockblock,brickbrick,callousedhandcallousedhand.
# began21monthsagodepthswinterendautumnnight.
# victorychangeseek.chancechange.happenwaythings.
# happen,newspiritservice,newspiritsacrifice.
# letsummonnewspiritpatriotism,responsibility,resolvespitchworkharderlook.
# Letremember,financialcrisistaught,thrivingWallStreetMainStreetsuffers.
# country,risefallnation,people.Letresisttemptationfallpartisanshippettinessimmaturitypoisonedpoliticslong.
# LetremembermanstatecarriedbannerRepublicanPartyWhiteHouse,partyfoundedvaluesself-relianceindividuallibertynationalunity.
# valuesshare.DemocraticPartywongreatvictorytonight,measurehumilitydeterminationhealdividesheldprogress.
# Lincolnsaidnationfardivided,enemiesfriends.passionstrained,breakbondsaffection.
# Americanssupportearn,wonvotetonight,hearvoices.needhelp.president,.
# watchingtonightshores,parliamentspalaces,huddledradiosforgottencornersworld,storiessingular,destinyshared,newdawnAmericanleadershiphand.
# —tearworld:defeat.seekpeacesecurity:support.wonderedAmericabeaconburnsbright:Tonightprovedtruestrengthnationcomesarmsscalewealth,enduringpowerideals:democracy,liberty,opportunityunyieldinghope.
# truegeniusAmerica:Americachange.unionperfected.achievedgiveshopeachievetomorrow.
# electionfirstsstoriestoldgenerations.mindtonightwomancastballotAtlanta.lotlikemillionsstoodlinevoiceheardelectionthing:AnnNixonCooper106yearsold.
# borngenerationpastslavery;timecarsroadplanessky;likevotereasons—womancolorskin.
# tonight,thinkseencenturyAmerica—heartachehope;struggleprogress;timestold,peoplepressedAmericancreed:Yes.
# timewomenvoicessilencedhopesdismissed,livedstandspeakreachballot.Yes.
# despairdustbowldepressionland,sawnationconquerfearNewDeal,newjobs,newsensecommonpurpose.Yes.
# bombsfellharbortyrannythreatenedworld,witnessgenerationrisegreatnessdemocracysaved.Yes.
# busesMontgomery,hosesBirmingham,bridgeSelma,preacherAtlantatoldpeople“ShallOvercome.”Yes.
# mantouchedmoon,wallcameBerlin,worldconnectedscienceimagination.
# year,election,touchedfingerscreen,castvote,106yearsAmerica,besttimesdarkesthours,knowsAmericachange.
# Yes.
# America,comefar.seen..tonight,letask—childrenlivecentury;daughtersluckylivelongAnnNixonCooper,change?progress?
# chanceanswer.moment.
# time,peopleworkopendoorsopportunitykids;restoreprosperitypromotecausepeace;reclaimAmericandreamreaffirmfundamentaltruth,,,;breathe,hope.metcynicismdoubtstell,respondtimelesscreedsumsspiritpeople:Yes,.[

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# </br> * Para este caso se filtran las palabras que no son stop words mediante la iteracion con el bucle for usando el atributo is_stop del token.
# </br> * Posteriormente se unifican las palabras filtrdas en un nuevo objeto que tendra la informacion de texto sin stop words.
# <hr>

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 6.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué atributo del token contiene la etiqueta NER?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
# El atributo que contiene la etiqueta NER es ent_type_
# Iterando el documento por los tokens.
for token in doc:
    print(f"Token: {token.text}, Etiqueta NER: {token.ent_type_}")
# Out:
# Token: “, Etiqueta NER:
# Token: Hello, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: Chicago, Etiqueta NER: GPE
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: If, Etiqueta NER:
# Token: there, Etiqueta NER:
# Token: is, Etiqueta NER:
# Token: anyone, Etiqueta NER:
# Token: out, Etiqueta NER:
# Token: there, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: still, Etiqueta NER:
# Token: doubts, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: America, Etiqueta NER: GPE
# Token: is, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: place, Etiqueta NER:
# Token: where, Etiqueta NER:
# Token: all, Etiqueta NER:
# Token: things, Etiqueta NER:
# Token: are, Etiqueta NER:
# Token: possible, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: still, Etiqueta NER:
# Token: wonders, Etiqueta NER:
# Token: if, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: dream, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: founders, Etiqueta NER:
# Token: is, Etiqueta NER:
# Token: alive, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: time, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: still, Etiqueta NER:
# Token: questions, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: power, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: democracy, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: tonight, Etiqueta NER: TIME
# Token: is, Etiqueta NER:
# Token: your, Etiqueta NER:
# Token: answer, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: It, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: answer, Etiqueta NER:
# Token: told, Etiqueta NER:
# Token: by, Etiqueta NER:
# Token: lines, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: stretched, Etiqueta NER:
# Token: around, Etiqueta NER:
# Token: schools, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: churches, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: numbers, Etiqueta NER:
# Token: this, Etiqueta NER:
# Token: nation, Etiqueta NER:
# Token: has, Etiqueta NER:
# Token: never, Etiqueta NER:
# Token: seen, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: by, Etiqueta NER:
# Token: people, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: waited, Etiqueta NER:
# Token: three, Etiqueta NER: TIME
# Token: hours, Etiqueta NER: TIME
# Token: and, Etiqueta NER:
# Token: four, Etiqueta NER: TIME
# Token: hours, Etiqueta NER: TIME
# Token: ,, Etiqueta NER:
# Token: many, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: first, Etiqueta NER: ORDINAL
# Token: time, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: their, Etiqueta NER:
# Token: lives, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: because, Etiqueta NER:
# Token: they, Etiqueta NER:
# Token: believed, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: this, Etiqueta NER:
# Token: time, Etiqueta NER:
# Token: must, Etiqueta NER:
# Token: be, Etiqueta NER:
# Token: different, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: their, Etiqueta NER:
# Token: voices, Etiqueta NER:
# Token: could, Etiqueta NER:
# Token: be, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: difference, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: It, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: answer, Etiqueta NER:
# Token: spoken, Etiqueta NER:
# Token: by, Etiqueta NER:
# Token: young, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: old, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: rich, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: poor, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: Democrat, Etiqueta NER: NORP
# Token: and, Etiqueta NER:
# Token: Republican, Etiqueta NER: NORP
# Token: ,, Etiqueta NER:
# Token: black, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: white, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: Hispanic, Etiqueta NER: NORP
# Token: ,, Etiqueta NER:
# Token: Asian, Etiqueta NER: NORP
# Token: ,, Etiqueta NER:
# Token: Native, Etiqueta NER: NORP
# Token: American, Etiqueta NER: NORP
# Token: ,, Etiqueta NER:
# Token: gay, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: straight, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: disabled, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: not, Etiqueta NER:
# Token: disabled, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: Americans, Etiqueta NER: NORP
# Token: who, Etiqueta NER:
# Token: sent, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: message, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: world, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: have, Etiqueta NER:
# Token: never, Etiqueta NER:
# Token: been, Etiqueta NER:
# Token: just, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: collection, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: individuals, Etiqueta NER:
# Token: or, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: collection, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: red, Etiqueta NER:
# Token: states, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: blue, Etiqueta NER:
# Token: states, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: We, Etiqueta NER:
# Token: are, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: always, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: be, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: the, Etiqueta NER: GPE
# Token: United, Etiqueta NER: GPE
# Token: States, Etiqueta NER: GPE
# Token: of, Etiqueta NER: GPE
# Token: America, Etiqueta NER: GPE
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: It, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: answer, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: led, Etiqueta NER:
# Token: those, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: ’ve, Etiqueta NER:
# Token: been, Etiqueta NER:
# Token: told, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: so, Etiqueta NER:
# Token: long, Etiqueta NER:
# Token: by, Etiqueta NER:
# Token: so, Etiqueta NER:
# Token: many, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: be, Etiqueta NER:
# Token: cynical, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: fearful, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: doubtful, Etiqueta NER:
# Token: about, Etiqueta NER:
# Token: what, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: can, Etiqueta NER:
# Token: achieve, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: put, Etiqueta NER:
# Token: their, Etiqueta NER:
# Token: hands, Etiqueta NER:
# Token: on, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: arc, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: history, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: bend, Etiqueta NER:
# Token: it, Etiqueta NER:
# Token: once, Etiqueta NER:
# Token: more, Etiqueta NER:
# Token: toward, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: hope, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: better, Etiqueta NER:
# Token: day, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: It, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: been, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: long, Etiqueta NER:
# Token: time, Etiqueta NER:
# Token: coming, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: but, Etiqueta NER:
# Token: tonight, Etiqueta NER: TIME
# Token: ,, Etiqueta NER:
# Token: because, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: what, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: did, Etiqueta NER:
# Token: on, Etiqueta NER:
# Token: this, Etiqueta NER:
# Token: date, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: this, Etiqueta NER:
# Token: election, Etiqueta NER:
# Token: at, Etiqueta NER:
# Token: this, Etiqueta NER:
# Token: defining, Etiqueta NER:
# Token: moment, Etiqueta NER:
# Token: change, Etiqueta NER:
# Token: has, Etiqueta NER:
# Token: come, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: America, Etiqueta NER: GPE
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: [, Etiqueta NER:
# Token: read, Etiqueta NER:
# Token: more, Etiqueta NER:
# Token: ], Etiqueta NER:
# Token:
#
# , Etiqueta NER:
# Token: We, Etiqueta NER:
# Token: did, Etiqueta NER:
# Token: n’t, Etiqueta NER:
# Token: start, Etiqueta NER:
# Token: with, Etiqueta NER:
# Token: much, Etiqueta NER:
# Token: money, Etiqueta NER:
# Token: or, Etiqueta NER:
# Token: many, Etiqueta NER:
# Token: endorsements, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: Our, Etiqueta NER:
# Token: campaign, Etiqueta NER:
# Token: was, Etiqueta NER:
# Token: not, Etiqueta NER:
# Token: hatched, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: halls, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: Washington, Etiqueta NER: GPE
# Token: ., Etiqueta NER:
# Token: It, Etiqueta NER:
# Token: began, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: backyards, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: Des, Etiqueta NER: GPE
# Token: Moines, Etiqueta NER: GPE
# Token: and, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: living, Etiqueta NER:
# Token: rooms, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: Concord, Etiqueta NER: GPE
# Token: and, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: front, Etiqueta NER:
# Token: porches, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: Charleston, Etiqueta NER: GPE
# Token: ., Etiqueta NER:
# Token: It, Etiqueta NER:
# Token: was, Etiqueta NER:
# Token: built, Etiqueta NER:
# Token: by, Etiqueta NER:
# Token: working, Etiqueta NER:
# Token: men, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: women, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: dug, Etiqueta NER:
# Token: into, Etiqueta NER:
# Token: what, Etiqueta NER:
# Token: little, Etiqueta NER:
# Token: savings, Etiqueta NER:
# Token: they, Etiqueta NER:
# Token: had, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: give, Etiqueta NER:
# Token: $, Etiqueta NER: MONEY
# Token: 5, Etiqueta NER: MONEY
# Token: and, Etiqueta NER: MONEY
# Token: $, Etiqueta NER: MONEY
# Token: 10, Etiqueta NER: MONEY
# Token: and, Etiqueta NER: MONEY
# Token: $, Etiqueta NER: MONEY
# Token: 20, Etiqueta NER: MONEY
# Token: to, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: cause, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: It, Etiqueta NER:
# Token: grew, Etiqueta NER:
# Token: strength, Etiqueta NER:
# Token: from, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: young, Etiqueta NER:
# Token: people, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: rejected, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: myth, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: their, Etiqueta NER:
# Token: generation, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: apathy, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: left, Etiqueta NER:
# Token: their, Etiqueta NER:
# Token: homes, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: their, Etiqueta NER:
# Token: families, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: jobs, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: offered, Etiqueta NER:
# Token: little, Etiqueta NER:
# Token: pay, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: less, Etiqueta NER:
# Token: sleep, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: It, Etiqueta NER:
# Token: drew, Etiqueta NER:
# Token: strength, Etiqueta NER:
# Token: from, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: not, Etiqueta NER:
# Token: -, Etiqueta NER:
# Token: so, Etiqueta NER:
# Token: -, Etiqueta NER:
# Token: young, Etiqueta NER:
# Token: people, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: braved, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: bitter, Etiqueta NER:
# Token: cold, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: scorching, Etiqueta NER:
# Token: heat, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: knock, Etiqueta NER:
# Token: on, Etiqueta NER:
# Token: doors, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: perfect, Etiqueta NER:
# Token: strangers, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: from, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: millions, Etiqueta NER: CARDINAL
# Token: of, Etiqueta NER:
# Token: Americans, Etiqueta NER: NORP
# Token: who, Etiqueta NER:
# Token: volunteered, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: organized, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: proved, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: more, Etiqueta NER: DATE
# Token: than, Etiqueta NER: DATE
# Token: two, Etiqueta NER: DATE
# Token: centuries, Etiqueta NER: DATE
# Token: later, Etiqueta NER: DATE
# Token: a, Etiqueta NER:
# Token: government, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: people, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: by, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: people, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: people, Etiqueta NER:
# Token: has, Etiqueta NER:
# Token: not, Etiqueta NER:
# Token: perished, Etiqueta NER:
# Token: from, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: Earth, Etiqueta NER: LOC
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: This, Etiqueta NER:
# Token: is, Etiqueta NER:
# Token: your, Etiqueta NER:
# Token: victory, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: And, Etiqueta NER:
# Token: I, Etiqueta NER:
# Token: know, Etiqueta NER:
# Token: you, Etiqueta NER:
# Token: did, Etiqueta NER:
# Token: n’t, Etiqueta NER:
# Token: do, Etiqueta NER:
# Token: this, Etiqueta NER:
# Token: just, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: win, Etiqueta NER:
# Token: an, Etiqueta NER:
# Token: election, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: And, Etiqueta NER:
# Token: I, Etiqueta NER:
# Token: know, Etiqueta NER:
# Token: you, Etiqueta NER:
# Token: did, Etiqueta NER:
# Token: n’t, Etiqueta NER:
# Token: do, Etiqueta NER:
# Token: it, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: me, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: You, Etiqueta NER:
# Token: did, Etiqueta NER:
# Token: it, Etiqueta NER:
# Token: because, Etiqueta NER:
# Token: you, Etiqueta NER:
# Token: understand, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: enormity, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: task, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: lies, Etiqueta NER:
# Token: ahead, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: For, Etiqueta NER:
# Token: even, Etiqueta NER:
# Token: as, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: celebrate, Etiqueta NER:
# Token: tonight, Etiqueta NER: TIME
# Token: ,, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: know, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: challenges, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: tomorrow, Etiqueta NER: DATE
# Token: will, Etiqueta NER:
# Token: bring, Etiqueta NER:
# Token: are, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: greatest, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: lifetime, Etiqueta NER:
# Token: —, Etiqueta NER:
# Token: two, Etiqueta NER: CARDINAL
# Token: wars, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: planet, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: peril, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: worst, Etiqueta NER:
# Token: financial, Etiqueta NER:
# Token: crisis, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: a, Etiqueta NER: DATE
# Token: century, Etiqueta NER: DATE
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: Even, Etiqueta NER:
# Token: as, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: stand, Etiqueta NER:
# Token: here, Etiqueta NER:
# Token: tonight, Etiqueta NER: TIME
# Token: ,, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: know, Etiqueta NER:
# Token: there, Etiqueta NER:
# Token: are, Etiqueta NER:
# Token: brave, Etiqueta NER:
# Token: Americans, Etiqueta NER: NORP
# Token: waking, Etiqueta NER:
# Token: up, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: deserts, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: Iraq, Etiqueta NER: GPE
# Token: and, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: mountains, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: Afghanistan, Etiqueta NER: GPE
# Token: to, Etiqueta NER:
# Token: risk, Etiqueta NER:
# Token: their, Etiqueta NER:
# Token: lives, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: us, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: There, Etiqueta NER:
# Token: are, Etiqueta NER:
# Token: mothers, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: fathers, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: lie, Etiqueta NER:
# Token: awake, Etiqueta NER:
# Token: after, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: children, Etiqueta NER:
# Token: fall, Etiqueta NER:
# Token: asleep, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: wonder, Etiqueta NER:
# Token: how, Etiqueta NER:
# Token: they, Etiqueta NER:
# Token: ’ll, Etiqueta NER:
# Token: make, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: mortgage, Etiqueta NER:
# Token: or, Etiqueta NER:
# Token: pay, Etiqueta NER:
# Token: their, Etiqueta NER:
# Token: doctors, Etiqueta NER:
# Token: ’, Etiqueta NER:
# Token: bills, Etiqueta NER:
# Token: or, Etiqueta NER:
# Token: save, Etiqueta NER:
# Token: enough, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: their, Etiqueta NER:
# Token: child, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: college, Etiqueta NER:
# Token: education, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: There, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: new, Etiqueta NER:
# Token: energy, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: harness, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: new, Etiqueta NER:
# Token: jobs, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: be, Etiqueta NER:
# Token: created, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: new, Etiqueta NER:
# Token: schools, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: build, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: threats, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: meet, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: alliances, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: repair, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: The, Etiqueta NER:
# Token: road, Etiqueta NER:
# Token: ahead, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: be, Etiqueta NER:
# Token: long, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: Our, Etiqueta NER:
# Token: climb, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: be, Etiqueta NER:
# Token: steep, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: We, Etiqueta NER:
# Token: may, Etiqueta NER:
# Token: not, Etiqueta NER:
# Token: get, Etiqueta NER:
# Token: there, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: one, Etiqueta NER: DATE
# Token: year, Etiqueta NER: DATE
# Token: or, Etiqueta NER:
# Token: even, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: one, Etiqueta NER: CARDINAL
# Token: term, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: But, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: America, Etiqueta NER: GPE
# Token: ,, Etiqueta NER:
# Token: I, Etiqueta NER:
# Token: have, Etiqueta NER:
# Token: never, Etiqueta NER:
# Token: been, Etiqueta NER:
# Token: more, Etiqueta NER:
# Token: hopeful, Etiqueta NER:
# Token: than, Etiqueta NER:
# Token: I, Etiqueta NER:
# Token: am, Etiqueta NER:
# Token: tonight, Etiqueta NER: TIME
# Token: that, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: get, Etiqueta NER:
# Token: there, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: I, Etiqueta NER:
# Token: promise, Etiqueta NER:
# Token: you, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: as, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: people, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: get, Etiqueta NER:
# Token: there, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: There, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: be, Etiqueta NER:
# Token: setbacks, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: false, Etiqueta NER:
# Token: starts, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: There, Etiqueta NER:
# Token: are, Etiqueta NER:
# Token: many, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: wo, Etiqueta NER:
# Token: n’t, Etiqueta NER:
# Token: agree, Etiqueta NER:
# Token: with, Etiqueta NER:
# Token: every, Etiqueta NER:
# Token: decision, Etiqueta NER:
# Token: or, Etiqueta NER:
# Token: policy, Etiqueta NER:
# Token: I, Etiqueta NER:
# Token: make, Etiqueta NER:
# Token: as, Etiqueta NER:
# Token: president, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: And, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: know, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: government, Etiqueta NER:
# Token: ca, Etiqueta NER:
# Token: n’t, Etiqueta NER:
# Token: solve, Etiqueta NER:
# Token: every, Etiqueta NER:
# Token: problem, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: But, Etiqueta NER:
# Token: I, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: always, Etiqueta NER:
# Token: be, Etiqueta NER:
# Token: honest, Etiqueta NER:
# Token: with, Etiqueta NER:
# Token: you, Etiqueta NER:
# Token: about, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: challenges, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: face, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: I, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: listen, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: you, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: especially, Etiqueta NER:
# Token: when, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: disagree, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: And, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: above, Etiqueta NER:
# Token: all, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: I, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: ask, Etiqueta NER:
# Token: you, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: join, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: work, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: remaking, Etiqueta NER:
# Token: this, Etiqueta NER:
# Token: nation, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: only, Etiqueta NER:
# Token: way, Etiqueta NER:
# Token: it, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: been, Etiqueta NER:
# Token: done, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: America, Etiqueta NER: GPE
# Token: for, Etiqueta NER:
# Token: 221, Etiqueta NER: DATE
# Token: years, Etiqueta NER: DATE
# Token: —, Etiqueta NER:
# Token: block, Etiqueta NER:
# Token: by, Etiqueta NER:
# Token: block, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: brick, Etiqueta NER:
# Token: by, Etiqueta NER:
# Token: brick, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: calloused, Etiqueta NER:
# Token: hand, Etiqueta NER:
# Token: by, Etiqueta NER:
# Token: calloused, Etiqueta NER:
# Token: hand, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: What, Etiqueta NER:
# Token: began, Etiqueta NER:
# Token: 21, Etiqueta NER: DATE
# Token: months, Etiqueta NER: DATE
# Token: ago, Etiqueta NER: DATE
# Token: in, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: depths, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: winter, Etiqueta NER: DATE
# Token: can, Etiqueta NER:
# Token: not, Etiqueta NER:
# Token: end, Etiqueta NER:
# Token: on, Etiqueta NER:
# Token: this, Etiqueta NER: TIME
# Token: autumn, Etiqueta NER: TIME
# Token: night, Etiqueta NER: TIME
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: This, Etiqueta NER:
# Token: victory, Etiqueta NER:
# Token: alone, Etiqueta NER:
# Token: is, Etiqueta NER:
# Token: not, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: change, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: seek, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: It, Etiqueta NER:
# Token: is, Etiqueta NER:
# Token: only, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: chance, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: us, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: make, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: change, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: And, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: can, Etiqueta NER:
# Token: not, Etiqueta NER:
# Token: happen, Etiqueta NER:
# Token: if, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: go, Etiqueta NER:
# Token: back, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: way, Etiqueta NER:
# Token: things, Etiqueta NER:
# Token: were, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: It, Etiqueta NER:
# Token: ca, Etiqueta NER:
# Token: n’t, Etiqueta NER:
# Token: happen, Etiqueta NER:
# Token: without, Etiqueta NER:
# Token: you, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: without, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: new, Etiqueta NER:
# Token: spirit, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: service, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: new, Etiqueta NER:
# Token: spirit, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: sacrifice, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: So, Etiqueta NER:
# Token: let, Etiqueta NER:
# Token: us, Etiqueta NER:
# Token: summon, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: new, Etiqueta NER:
# Token: spirit, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: patriotism, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: responsibility, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: where, Etiqueta NER:
# Token: each, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: us, Etiqueta NER:
# Token: resolves, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: pitch, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: work, Etiqueta NER:
# Token: harder, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: look, Etiqueta NER:
# Token: after, Etiqueta NER:
# Token: not, Etiqueta NER:
# Token: only, Etiqueta NER:
# Token: ourselves, Etiqueta NER:
# Token: but, Etiqueta NER:
# Token: each, Etiqueta NER:
# Token: other, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: Let, Etiqueta NER:
# Token: us, Etiqueta NER:
# Token: remember, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: if, Etiqueta NER:
# Token: this, Etiqueta NER:
# Token: financial, Etiqueta NER:
# Token: crisis, Etiqueta NER:
# Token: taught, Etiqueta NER:
# Token: us, Etiqueta NER:
# Token: anything, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: it, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: can, Etiqueta NER:
# Token: not, Etiqueta NER:
# Token: have, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: thriving, Etiqueta NER:
# Token: Wall, Etiqueta NER:
# Token: Street, Etiqueta NER:
# Token: while, Etiqueta NER:
# Token: Main, Etiqueta NER: FAC
# Token: Street, Etiqueta NER: FAC
# Token: suffers, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: In, Etiqueta NER:
# Token: this, Etiqueta NER:
# Token: country, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: rise, Etiqueta NER:
# Token: or, Etiqueta NER:
# Token: fall, Etiqueta NER:
# Token: as, Etiqueta NER:
# Token: one, Etiqueta NER: CARDINAL
# Token: nation, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: as, Etiqueta NER:
# Token: one, Etiqueta NER: CARDINAL
# Token: people, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: Let, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: resist, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: temptation, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: fall, Etiqueta NER:
# Token: back, Etiqueta NER:
# Token: on, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: same, Etiqueta NER:
# Token: partisanship, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: pettiness, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: immaturity, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: has, Etiqueta NER:
# Token: poisoned, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: politics, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: so, Etiqueta NER:
# Token: long, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: Let, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: remember, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: it, Etiqueta NER:
# Token: was, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: man, Etiqueta NER:
# Token: from, Etiqueta NER:
# Token: this, Etiqueta NER:
# Token: state, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: first, Etiqueta NER: ORDINAL
# Token: carried, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: banner, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: the, Etiqueta NER: ORG
# Token: Republican, Etiqueta NER: ORG
# Token: Party, Etiqueta NER: ORG
# Token: to, Etiqueta NER:
# Token: the, Etiqueta NER: ORG
# Token: White, Etiqueta NER: ORG
# Token: House, Etiqueta NER: ORG
# Token: ,, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: party, Etiqueta NER:
# Token: founded, Etiqueta NER:
# Token: on, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: values, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: self, Etiqueta NER:
# Token: -, Etiqueta NER:
# Token: reliance, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: individual, Etiqueta NER:
# Token: liberty, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: national, Etiqueta NER:
# Token: unity, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: Those, Etiqueta NER:
# Token: are, Etiqueta NER:
# Token: values, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: all, Etiqueta NER:
# Token: share, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: And, Etiqueta NER:
# Token: while, Etiqueta NER:
# Token: the, Etiqueta NER: ORG
# Token: Democratic, Etiqueta NER: ORG
# Token: Party, Etiqueta NER: ORG
# Token: has, Etiqueta NER:
# Token: won, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: great, Etiqueta NER:
# Token: victory, Etiqueta NER:
# Token: tonight, Etiqueta NER: TIME
# Token: ,, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: do, Etiqueta NER:
# Token: so, Etiqueta NER:
# Token: with, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: measure, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: humility, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: determination, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: heal, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: divides, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: have, Etiqueta NER:
# Token: held, Etiqueta NER:
# Token: back, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: progress, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: As, Etiqueta NER:
# Token: Lincoln, Etiqueta NER: ORG
# Token: said, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: nation, Etiqueta NER:
# Token: far, Etiqueta NER:
# Token: more, Etiqueta NER:
# Token: divided, Etiqueta NER:
# Token: than, Etiqueta NER:
# Token: ours, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: are, Etiqueta NER:
# Token: not, Etiqueta NER:
# Token: enemies, Etiqueta NER:
# Token: but, Etiqueta NER:
# Token: friends, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: Though, Etiqueta NER:
# Token: passion, Etiqueta NER:
# Token: may, Etiqueta NER:
# Token: have, Etiqueta NER:
# Token: strained, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: it, Etiqueta NER:
# Token: must, Etiqueta NER:
# Token: not, Etiqueta NER:
# Token: break, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: bonds, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: affection, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: And, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: those, Etiqueta NER:
# Token: Americans, Etiqueta NER: NORP
# Token: whose, Etiqueta NER:
# Token: support, Etiqueta NER:
# Token: I, Etiqueta NER:
# Token: have, Etiqueta NER:
# Token: yet, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: earn, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: I, Etiqueta NER:
# Token: may, Etiqueta NER:
# Token: not, Etiqueta NER:
# Token: have, Etiqueta NER:
# Token: won, Etiqueta NER:
# Token: your, Etiqueta NER:
# Token: vote, Etiqueta NER:
# Token: tonight, Etiqueta NER: TIME
# Token: ,, Etiqueta NER:
# Token: but, Etiqueta NER:
# Token: I, Etiqueta NER:
# Token: hear, Etiqueta NER:
# Token: your, Etiqueta NER:
# Token: voices, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: I, Etiqueta NER:
# Token: need, Etiqueta NER:
# Token: your, Etiqueta NER:
# Token: help, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: And, Etiqueta NER:
# Token: I, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: be, Etiqueta NER:
# Token: your, Etiqueta NER:
# Token: president, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: too, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: And, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: all, Etiqueta NER:
# Token: those, Etiqueta NER:
# Token: watching, Etiqueta NER:
# Token: tonight, Etiqueta NER: TIME
# Token: from, Etiqueta NER:
# Token: beyond, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: shores, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: from, Etiqueta NER:
# Token: parliaments, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: palaces, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: those, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: are, Etiqueta NER:
# Token: huddled, Etiqueta NER:
# Token: around, Etiqueta NER:
# Token: radios, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: forgotten, Etiqueta NER:
# Token: corners, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: world, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: stories, Etiqueta NER:
# Token: are, Etiqueta NER:
# Token: singular, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: but, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: destiny, Etiqueta NER:
# Token: is, Etiqueta NER:
# Token: shared, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: new, Etiqueta NER:
# Token: dawn, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: American, Etiqueta NER: NORP
# Token: leadership, Etiqueta NER:
# Token: is, Etiqueta NER:
# Token: at, Etiqueta NER:
# Token: hand, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: To, Etiqueta NER:
# Token: those, Etiqueta NER:
# Token: —, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: those, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: would, Etiqueta NER:
# Token: tear, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: world, Etiqueta NER:
# Token: down, Etiqueta NER:
# Token: :, Etiqueta NER:
# Token: We, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: defeat, Etiqueta NER:
# Token: you, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: To, Etiqueta NER:
# Token: those, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: seek, Etiqueta NER:
# Token: peace, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: security, Etiqueta NER:
# Token: :, Etiqueta NER:
# Token: We, Etiqueta NER:
# Token: support, Etiqueta NER:
# Token: you, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: And, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: all, Etiqueta NER:
# Token: those, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: have, Etiqueta NER:
# Token: wondered, Etiqueta NER:
# Token: if, Etiqueta NER:
# Token: America, Etiqueta NER: GPE
# Token: ’s, Etiqueta NER:
# Token: beacon, Etiqueta NER:
# Token: still, Etiqueta NER:
# Token: burns, Etiqueta NER:
# Token: as, Etiqueta NER:
# Token: bright, Etiqueta NER:
# Token: :, Etiqueta NER:
# Token: Tonight, Etiqueta NER: TIME
# Token: we, Etiqueta NER:
# Token: proved, Etiqueta NER:
# Token: once, Etiqueta NER:
# Token: more, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: true, Etiqueta NER:
# Token: strength, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: nation, Etiqueta NER:
# Token: comes, Etiqueta NER:
# Token: not, Etiqueta NER:
# Token: from, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: might, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: arms, Etiqueta NER:
# Token: or, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: scale, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: wealth, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: but, Etiqueta NER:
# Token: from, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: enduring, Etiqueta NER:
# Token: power, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: ideals, Etiqueta NER:
# Token: :, Etiqueta NER:
# Token: democracy, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: liberty, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: opportunity, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: unyielding, Etiqueta NER:
# Token: hope, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: That, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: true, Etiqueta NER:
# Token: genius, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: America, Etiqueta NER: GPE
# Token: :, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: America, Etiqueta NER: GPE
# Token: can, Etiqueta NER:
# Token: change, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: Our, Etiqueta NER:
# Token: union, Etiqueta NER:
# Token: can, Etiqueta NER:
# Token: be, Etiqueta NER:
# Token: perfected, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: What, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: ’ve, Etiqueta NER:
# Token: already, Etiqueta NER:
# Token: achieved, Etiqueta NER:
# Token: gives, Etiqueta NER:
# Token: us, Etiqueta NER:
# Token: hope, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: what, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: can, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: must, Etiqueta NER:
# Token: achieve, Etiqueta NER:
# Token: tomorrow, Etiqueta NER: DATE
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: This, Etiqueta NER:
# Token: election, Etiqueta NER:
# Token: had, Etiqueta NER:
# Token: many, Etiqueta NER:
# Token: firsts, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: many, Etiqueta NER:
# Token: stories, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: be, Etiqueta NER:
# Token: told, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: generations, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: But, Etiqueta NER:
# Token: one, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: on, Etiqueta NER:
# Token: my, Etiqueta NER:
# Token: mind, Etiqueta NER:
# Token: tonight, Etiqueta NER: TIME
# Token: ’s, Etiqueta NER:
# Token: about, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: woman, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: cast, Etiqueta NER:
# Token: her, Etiqueta NER:
# Token: ballot, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: Atlanta, Etiqueta NER: GPE
# Token: ., Etiqueta NER:
# Token: She, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: lot, Etiqueta NER:
# Token: like, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: millions, Etiqueta NER: CARDINAL
# Token: of, Etiqueta NER:
# Token: others, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: stood, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: line, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: make, Etiqueta NER:
# Token: their, Etiqueta NER:
# Token: voice, Etiqueta NER:
# Token: heard, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: this, Etiqueta NER:
# Token: election, Etiqueta NER:
# Token: except, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: one, Etiqueta NER: CARDINAL
# Token: thing, Etiqueta NER:
# Token: :, Etiqueta NER:
# Token: Ann, Etiqueta NER: PERSON
# Token: Nixon, Etiqueta NER: PERSON
# Token: Cooper, Etiqueta NER: PERSON
# Token: is, Etiqueta NER:
# Token: 106, Etiqueta NER: DATE
# Token: years, Etiqueta NER: DATE
# Token: old, Etiqueta NER: DATE
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: She, Etiqueta NER:
# Token: was, Etiqueta NER:
# Token: born, Etiqueta NER:
# Token: just, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: generation, Etiqueta NER:
# Token: past, Etiqueta NER:
# Token: slavery, Etiqueta NER:
# Token: ;, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: time, Etiqueta NER:
# Token: when, Etiqueta NER:
# Token: there, Etiqueta NER:
# Token: were, Etiqueta NER:
# Token: no, Etiqueta NER:
# Token: cars, Etiqueta NER:
# Token: on, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: road, Etiqueta NER:
# Token: or, Etiqueta NER:
# Token: planes, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: sky, Etiqueta NER:
# Token: ;, Etiqueta NER:
# Token: when, Etiqueta NER:
# Token: someone, Etiqueta NER:
# Token: like, Etiqueta NER:
# Token: her, Etiqueta NER:
# Token: could, Etiqueta NER:
# Token: n’t, Etiqueta NER:
# Token: vote, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: two, Etiqueta NER: CARDINAL
# Token: reasons, Etiqueta NER:
# Token: —, Etiqueta NER:
# Token: because, Etiqueta NER:
# Token: she, Etiqueta NER:
# Token: was, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: woman, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: because, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: color, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: her, Etiqueta NER:
# Token: skin, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: And, Etiqueta NER:
# Token: tonight, Etiqueta NER: TIME
# Token: ,, Etiqueta NER:
# Token: I, Etiqueta NER:
# Token: think, Etiqueta NER:
# Token: about, Etiqueta NER:
# Token: all, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: she, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: seen, Etiqueta NER:
# Token: throughout, Etiqueta NER:
# Token: her, Etiqueta NER:
# Token: century, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: America, Etiqueta NER: GPE
# Token: —, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: heartache, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: hope, Etiqueta NER:
# Token: ;, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: struggle, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: progress, Etiqueta NER:
# Token: ;, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: times, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: were, Etiqueta NER:
# Token: told, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: ca, Etiqueta NER:
# Token: n’t, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: people, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: pressed, Etiqueta NER:
# Token: on, Etiqueta NER:
# Token: with, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: American, Etiqueta NER: NORP
# Token: creed, Etiqueta NER:
# Token: :, Etiqueta NER:
# Token: Yes, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: can, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: At, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: time, Etiqueta NER:
# Token: when, Etiqueta NER:
# Token: women, Etiqueta NER:
# Token: ’s, Etiqueta NER:
# Token: voices, Etiqueta NER:
# Token: were, Etiqueta NER:
# Token: silenced, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: their, Etiqueta NER:
# Token: hopes, Etiqueta NER:
# Token: dismissed, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: she, Etiqueta NER:
# Token: lived, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: see, Etiqueta NER:
# Token: them, Etiqueta NER:
# Token: stand, Etiqueta NER:
# Token: up, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: speak, Etiqueta NER:
# Token: out, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: reach, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: ballot, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: Yes, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: can, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: When, Etiqueta NER:
# Token: there, Etiqueta NER:
# Token: was, Etiqueta NER:
# Token: despair, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: dust, Etiqueta NER:
# Token: bowl, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: depression, Etiqueta NER:
# Token: across, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: land, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: she, Etiqueta NER:
# Token: saw, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: nation, Etiqueta NER:
# Token: conquer, Etiqueta NER:
# Token: fear, Etiqueta NER:
# Token: itself, Etiqueta NER:
# Token: with, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: New, Etiqueta NER:
# Token: Deal, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: new, Etiqueta NER:
# Token: jobs, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: new, Etiqueta NER:
# Token: sense, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: common, Etiqueta NER:
# Token: purpose, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: Yes, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: can, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: When, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: bombs, Etiqueta NER:
# Token: fell, Etiqueta NER:
# Token: on, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: harbor, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: tyranny, Etiqueta NER:
# Token: threatened, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: world, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: she, Etiqueta NER:
# Token: was, Etiqueta NER:
# Token: there, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: witness, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: generation, Etiqueta NER:
# Token: rise, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: greatness, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: democracy, Etiqueta NER:
# Token: was, Etiqueta NER:
# Token: saved, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: Yes, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: can, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: She, Etiqueta NER:
# Token: was, Etiqueta NER:
# Token: there, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: buses, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: Montgomery, Etiqueta NER: ORG
# Token: ,, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: hoses, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: Birmingham, Etiqueta NER: GPE
# Token: ,, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: bridge, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: Selma, Etiqueta NER: GPE
# Token: ,, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: preacher, Etiqueta NER:
# Token: from, Etiqueta NER:
# Token: Atlanta, Etiqueta NER: GPE
# Token: who, Etiqueta NER:
# Token: told, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: people, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: “, Etiqueta NER:
# Token: We, Etiqueta NER:
# Token: Shall, Etiqueta NER:
# Token: Overcome, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: ”, Etiqueta NER:
# Token: Yes, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: can, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: A, Etiqueta NER:
# Token: man, Etiqueta NER:
# Token: touched, Etiqueta NER:
# Token: down, Etiqueta NER:
# Token: on, Etiqueta NER:
# Token: the, Etiqueta NER: LOC
# Token: moon, Etiqueta NER: LOC
# Token: ,, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: wall, Etiqueta NER:
# Token: came, Etiqueta NER:
# Token: down, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: Berlin, Etiqueta NER: GPE
# Token: ,, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: world, Etiqueta NER:
# Token: was, Etiqueta NER:
# Token: connected, Etiqueta NER:
# Token: by, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: own, Etiqueta NER:
# Token: science, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: imagination, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: And, Etiqueta NER:
# Token: this, Etiqueta NER: DATE
# Token: year, Etiqueta NER: DATE
# Token: ,, Etiqueta NER:
# Token: in, Etiqueta NER:
# Token: this, Etiqueta NER:
# Token: election, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: she, Etiqueta NER:
# Token: touched, Etiqueta NER:
# Token: her, Etiqueta NER:
# Token: finger, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: screen, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: cast, Etiqueta NER:
# Token: her, Etiqueta NER:
# Token: vote, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: because, Etiqueta NER:
# Token: after, Etiqueta NER:
# Token: 106, Etiqueta NER: DATE
# Token: years, Etiqueta NER: DATE
# Token: in, Etiqueta NER:
# Token: America, Etiqueta NER: GPE
# Token: ,, Etiqueta NER:
# Token: through, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: best, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: times, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: darkest, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: hours, Etiqueta NER: TIME
# Token: ,, Etiqueta NER:
# Token: she, Etiqueta NER:
# Token: knows, Etiqueta NER:
# Token: how, Etiqueta NER:
# Token: America, Etiqueta NER: GPE
# Token: can, Etiqueta NER:
# Token: change, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: Yes, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: can, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: America, Etiqueta NER: GPE
# Token: ,, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: have, Etiqueta NER:
# Token: come, Etiqueta NER:
# Token: so, Etiqueta NER:
# Token: far, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: We, Etiqueta NER:
# Token: have, Etiqueta NER:
# Token: seen, Etiqueta NER:
# Token: so, Etiqueta NER:
# Token: much, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: But, Etiqueta NER:
# Token: there, Etiqueta NER:
# Token: is, Etiqueta NER:
# Token: so, Etiqueta NER:
# Token: much, Etiqueta NER:
# Token: more, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: do, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: So, Etiqueta NER:
# Token: tonight, Etiqueta NER: TIME
# Token: ,, Etiqueta NER:
# Token: let, Etiqueta NER:
# Token: us, Etiqueta NER:
# Token: ask, Etiqueta NER:
# Token: ourselves, Etiqueta NER:
# Token: —, Etiqueta NER:
# Token: if, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: children, Etiqueta NER:
# Token: should, Etiqueta NER:
# Token: live, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: see, Etiqueta NER:
# Token: the, Etiqueta NER: DATE
# Token: next, Etiqueta NER: DATE
# Token: century, Etiqueta NER: DATE
# Token: ;, Etiqueta NER:
# Token: if, Etiqueta NER:
# Token: my, Etiqueta NER:
# Token: daughters, Etiqueta NER:
# Token: should, Etiqueta NER:
# Token: be, Etiqueta NER:
# Token: so, Etiqueta NER:
# Token: lucky, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: live, Etiqueta NER:
# Token: as, Etiqueta NER:
# Token: long, Etiqueta NER:
# Token: as, Etiqueta NER:
# Token: Ann, Etiqueta NER: PERSON
# Token: Nixon, Etiqueta NER: PERSON
# Token: Cooper, Etiqueta NER: PERSON
# Token: ,, Etiqueta NER:
# Token: what, Etiqueta NER:
# Token: change, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: they, Etiqueta NER:
# Token: see, Etiqueta NER:
# Token: ?, Etiqueta NER:
# Token: What, Etiqueta NER:
# Token: progress, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: have, Etiqueta NER:
# Token: made, Etiqueta NER:
# Token: ?, Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: This, Etiqueta NER:
# Token: is, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: chance, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: answer, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: call, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: This, Etiqueta NER:
# Token: is, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: moment, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token:
# , Etiqueta NER:
# Token: This, Etiqueta NER:
# Token: is, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: time, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: put, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: people, Etiqueta NER:
# Token: back, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: work, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: open, Etiqueta NER:
# Token: doors, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: opportunity, Etiqueta NER:
# Token: for, Etiqueta NER:
# Token: our, Etiqueta NER:
# Token: kids, Etiqueta NER:
# Token: ;, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: restore, Etiqueta NER:
# Token: prosperity, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: promote, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: cause, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: peace, Etiqueta NER:
# Token: ;, Etiqueta NER:
# Token: to, Etiqueta NER:
# Token: reclaim, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: American, Etiqueta NER: NORP
# Token: dream, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: reaffirm, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: fundamental, Etiqueta NER:
# Token: truth, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: out, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: many, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: are, Etiqueta NER:
# Token: one, Etiqueta NER:
# Token: ;, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: while, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: breathe, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: hope, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: And, Etiqueta NER:
# Token: where, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: are, Etiqueta NER:
# Token: met, Etiqueta NER:
# Token: with, Etiqueta NER:
# Token: cynicism, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: doubts, Etiqueta NER:
# Token: and, Etiqueta NER:
# Token: those, Etiqueta NER:
# Token: who, Etiqueta NER:
# Token: tell, Etiqueta NER:
# Token: us, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: ca, Etiqueta NER:
# Token: n’t, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: will, Etiqueta NER:
# Token: respond, Etiqueta NER:
# Token: with, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: timeless, Etiqueta NER:
# Token: creed, Etiqueta NER:
# Token: that, Etiqueta NER:
# Token: sums, Etiqueta NER:
# Token: up, Etiqueta NER:
# Token: the, Etiqueta NER:
# Token: spirit, Etiqueta NER:
# Token: of, Etiqueta NER:
# Token: a, Etiqueta NER:
# Token: people, Etiqueta NER:
# Token: :, Etiqueta NER:
# Token: Yes, Etiqueta NER:
# Token: ,, Etiqueta NER:
# Token: we, Etiqueta NER:
# Token: can, Etiqueta NER:
# Token: ., Etiqueta NER:
# Token: [, Etiqueta NER:

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# </br> * El atributo que contiene la etiqueta NER es ent_type_ para obtener el valor, se recorre el documento mediante un for tomando como referencia cada token del doc. y con el argumento ent_type_ propio del token se obtiene el valor.
# <hr>

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 7.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué entidades nombradas soporta Spacy?, ¿Qué significa cada una?</span>
#
# <b>Nota</b>: Debes escribir el código que liste las entidades disponibles y la explicación de las mismas. El listado sin código se considerará respuesta incompleta.

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
for entidad in doc.ents:
    print(f"Entidad: {entidad.text}, Tipo: {entidad.label_}")
# Out:
# Entidad: Chicago, Tipo: GPE
# Entidad: America, Tipo: GPE
# Entidad: tonight, Tipo: TIME
# Entidad: three hours, Tipo: TIME
# Entidad: four hours, Tipo: TIME
# Entidad: first, Tipo: ORDINAL
# Entidad: Democrat, Tipo: NORP
# Entidad: Republican, Tipo: NORP
# Entidad: Hispanic, Tipo: NORP
# Entidad: Asian, Tipo: NORP
# Entidad: Native American, Tipo: NORP
# Entidad: Americans, Tipo: NORP
# Entidad: the United States of America, Tipo: GPE
# Entidad: tonight, Tipo: TIME
# Entidad: America, Tipo: GPE
# Entidad: Washington, Tipo: GPE
# Entidad: Des Moines, Tipo: GPE
# Entidad: Concord, Tipo: GPE
# Entidad: Charleston, Tipo: GPE
# Entidad: $5 and $10 and $20, Tipo: MONEY
# Entidad: millions, Tipo: CARDINAL
# Entidad: Americans, Tipo: NORP
# Entidad: more than two centuries later, Tipo: DATE
# Entidad: Earth, Tipo: LOC
# Entidad: tonight, Tipo: TIME
# Entidad: tomorrow, Tipo: DATE
# Entidad: two, Tipo: CARDINAL
# Entidad: a century, Tipo: DATE
# Entidad: tonight, Tipo: TIME
# Entidad: Americans, Tipo: NORP
# Entidad: Iraq, Tipo: GPE
# Entidad: Afghanistan, Tipo: GPE
# Entidad: one year, Tipo: DATE
# Entidad: one, Tipo: CARDINAL
# Entidad: America, Tipo: GPE
# Entidad: tonight, Tipo: TIME
# Entidad: America, Tipo: GPE
# Entidad: 221 years, Tipo: DATE
# Entidad: 21 months ago, Tipo: DATE
# Entidad: winter, Tipo: DATE
# Entidad: this autumn night, Tipo: TIME
# Entidad: Main Street, Tipo: FAC
# Entidad: one, Tipo: CARDINAL
# Entidad: one, Tipo: CARDINAL
# Entidad: first, Tipo: ORDINAL
# Entidad: the Republican Party, Tipo: ORG
# Entidad: the White House, Tipo: ORG
# Entidad: the Democratic Party, Tipo: ORG
# Entidad: tonight, Tipo: TIME
# Entidad: Lincoln, Tipo: ORG
# Entidad: Americans, Tipo: NORP
# Entidad: tonight, Tipo: TIME
# Entidad: tonight, Tipo: TIME
# Entidad: American, Tipo: NORP
# Entidad: America, Tipo: GPE
# Entidad: Tonight, Tipo: TIME
# Entidad: America, Tipo: GPE
# Entidad: America, Tipo: GPE
# Entidad: tomorrow, Tipo: DATE
# Entidad: tonight, Tipo: TIME
# Entidad: Atlanta, Tipo: GPE
# Entidad: millions, Tipo: CARDINAL
# Entidad: one, Tipo: CARDINAL
# Entidad: Ann Nixon Cooper, Tipo: PERSON
# Entidad: 106 years old, Tipo: DATE
# Entidad: two, Tipo: CARDINAL
# Entidad: tonight, Tipo: TIME
# Entidad: America, Tipo: GPE
# Entidad: American, Tipo: NORP
# Entidad: Montgomery, Tipo: ORG
# Entidad: Birmingham, Tipo: GPE
# Entidad: Selma, Tipo: GPE
# Entidad: Atlanta, Tipo: GPE
# Entidad: the moon, Tipo: LOC
# Entidad: Berlin, Tipo: GPE
# Entidad: this year, Tipo: DATE
# Entidad: 106 years, Tipo: DATE
# Entidad: America, Tipo: GPE
# Entidad: hours, Tipo: TIME
# Entidad: America, Tipo: GPE
# Entidad: America, Tipo: GPE
# Entidad: tonight, Tipo: TIME
# Entidad: the next century, Tipo: DATE
# Entidad: Ann Nixon Cooper, Tipo: PERSON
# Entidad: American, Tipo: NORP

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# PERSON: Representa nombres de personas, tanto nombres propios como apellidos.</br>
# ORG: Representa organizaciones, nombres de empresas, instituciones, etc.</br>
# LOC: Representa ubicaciones geográficas, ciudades, países, ríos, montañas, etc.</br>
# GPE (Geo-Political Entity): Representa entidades políticas y geográficas, como países, estados, regiones, ciudades, etc.</br>
# DATE: Representa expresiones de fecha y tiempo, como fechas específicas, periodos de tiempo, horas, años, etc. </br>
# TIME: Representa horas y momentos específicos en el tiempo.</br>
# MONEY: Representa expresiones monetarias, como cantidades de dinero o monedas.</br>
# PERCENT: Representa porcentajes o valores numéricos seguidos de un signo de porcentaje (%).</br>
# QUANTITY: Representa cantidades y medidas, como números acompañados de unidades de medida.</br>
# CARDINAL: Representa números cardinales, como números enteros.</br>
# ORDINAL: Representa números ordinales, como "primer", "segundo", "tercero", etc.</br>
# PRODUCT: Representa nombres de productos y artículos.</br>
# EVENT: Representa eventos, conferencias, festivales y otros acontecimientos.</br>
# WORK_OF_ART: Representa obras de arte, como pinturas, libros, canciones, etc.</br>
# LAW: Representa leyes y regulaciones legales.</br>
# LANGUAGE: Representa nombres de idiomas.</br>
# NORP (Nationalities or Religious or Political Groups): Representa nacionalidades, grupos religiosos o políticos.</br>
# FAC (Facility): Representa instalaciones o edificios, como aeropuertos, hospitales, estaciones de tren, etc.</br>
# </br>
# <hr>

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 8.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué entidades nombradas diferentes son reconocidas en el texto?, ¿cuántas hay de cada tipo?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
conteo_entidades = {}
entidad_texto = None
entidad_tipo = None

for entidad in doc.ents:
    entidad_texto = entidad.text
    entidad_tipo = entidad.label_

    if entidad_texto in conteo_entidades:
        conteo_entidades[entidad_texto][0] += 1
    else:
        conteo_entidades[entidad_texto] = [1, entidad_tipo]

for entidad, (recuento, tipo) in conteo_entidades.items():
    print(f"Entidad: {entidad}, Tipo: {tipo}, Recuento: {recuento}")
# Out:
# Entidad: Chicago, Tipo: GPE, Recuento: 1
# Entidad: America, Tipo: GPE, Recuento: 11
# Entidad: tonight, Tipo: TIME, Recuento: 11
# Entidad: three hours, Tipo: TIME, Recuento: 1
# Entidad: four hours, Tipo: TIME, Recuento: 1
# Entidad: first, Tipo: ORDINAL, Recuento: 2
# Entidad: Democrat, Tipo: NORP, Recuento: 1
# Entidad: Republican, Tipo: NORP, Recuento: 1
# Entidad: Hispanic, Tipo: NORP, Recuento: 1
# Entidad: Asian, Tipo: NORP, Recuento: 1
# Entidad: Native American, Tipo: NORP, Recuento: 1
# Entidad: Americans, Tipo: NORP, Recuento: 4
# Entidad: the United States of America, Tipo: GPE, Recuento: 1
# Entidad: Washington, Tipo: GPE, Recuento: 1
# Entidad: Des Moines, Tipo: GPE, Recuento: 1
# Entidad: Concord, Tipo: GPE, Recuento: 1
# Entidad: Charleston, Tipo: GPE, Recuento: 1
# Entidad: $5 and $10 and $20, Tipo: MONEY, Recuento: 1
# Entidad: millions, Tipo: CARDINAL, Recuento: 2
# Entidad: more than two centuries later, Tipo: DATE, Recuento: 1
# Entidad: Earth, Tipo: LOC, Recuento: 1
# Entidad: tomorrow, Tipo: DATE, Recuento: 2
# Entidad: two, Tipo: CARDINAL, Recuento: 2
# Entidad: a century, Tipo: DATE, Recuento: 1
# Entidad: Iraq, Tipo: GPE, Recuento: 1
# Entidad: Afghanistan, Tipo: GPE, Recuento: 1
# Entidad: one year, Tipo: DATE, Recuento: 1
# Entidad: one, Tipo: CARDINAL, Recuento: 4
# Entidad: 221 years, Tipo: DATE, Recuento: 1
# Entidad: 21 months ago, Tipo: DATE, Recuento: 1
# Entidad: winter, Tipo: DATE, Recuento: 1
# Entidad: this autumn night, Tipo: TIME, Recuento: 1
# Entidad: Main Street, Tipo: FAC, Recuento: 1
# Entidad: the Republican Party, Tipo: ORG, Recuento: 1
# Entidad: the White House, Tipo: ORG, Recuento: 1
# Entidad: the Democratic Party, Tipo: ORG, Recuento: 1
# Entidad: Lincoln, Tipo: ORG, Recuento: 1
# Entidad: American, Tipo: NORP, Recuento: 3
# Entidad: Tonight, Tipo: TIME, Recuento: 1
# Entidad: Atlanta, Tipo: GPE, Recuento: 2
# Entidad: Ann Nixon Cooper, Tipo: PERSON, Recuento: 2
# Entidad: 106 years old, Tipo: DATE, Recuento: 1
# Entidad: Montgomery, Tipo: ORG, Recuento: 1
# Entidad: Birmingham, Tipo: GPE, Recuento: 1
# Entidad: Selma, Tipo: GPE, Recuento: 1
# Entidad: the moon, Tipo: LOC, Recuento: 1
# Entidad: Berlin, Tipo: GPE, Recuento: 1
# Entidad: this year, Tipo: DATE, Recuento: 1
# Entidad: 106 years, Tipo: DATE, Recuento: 1
# Entidad: hours, Tipo: TIME, Recuento: 1
# Entidad: the next century, Tipo: DATE, Recuento: 1

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# * para este caso se iteran las entidades del documento, obteniendo el texto y tipo de identidad, agregando la entidad al diccionario para realizar los incrementos, por ultimo se imprimen las entidades con los respectivos re conteos.</br>
# <hr>

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 9.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Explica con tus palabras qué es el código IOB para el reconocimiento de entiedades. Pon un ejemplo, sacado del texto, de una etiqueta de un único token y una etiqueta compuesta por varios tokens.</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 10.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué POS Tags aparecen en el texto, y cuántos hay tokens hay de cada uno?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
